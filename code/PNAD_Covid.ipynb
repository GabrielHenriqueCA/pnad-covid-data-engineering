# %% [markdown]
# # CAMADA BRONZE

# %% [markdown]
# ### Instalação de Bibliotecas
#
# Esta célula instala as bibliotecas necessárias para o projeto:
# - `pyspark==4.0.0`: A versão específica do Apache Spark para Python, utilizada para processamento de grandes volumes de dados.
# - `openpyxl`: Uma biblioteca para ler e escrever arquivos Excel (.xlsx).

# %%
# !pip install pyspark==4.0.0
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyspark==4.0.0
#   Downloading pyspark-4.0.0.tar.gz (434.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.1/434.1 MB 73.9 MB/s  0:00:04:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting py4j==0.10.9.9 (from pyspark==4.0.0)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml) ... done
#   Created wheel for pyspark: filename=pyspark-4.0.0-py2.py3-none-any.whl size=434741299 sha256=2d169bba91da7f843d28ee8c48b477d8c79e7a5d0b5787c2d73bcd12e09a83a8
#   Stored in directory: /home/jupyter-user/.cache/pip/wheels/11/95/4b/e3cfd6f160b2988f57207fcde6e5a4c6e0104d7da5a107eb8e
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pyspark]m1/2 [pyspark]
# Successfully installed py4j-0.10.9.9 pyspark-4.0.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
from awsglue.dynamicframe import DynamicFrame
from pyspark.sql.functions import col, lit

# %% [markdown]
# ### Inicialização da SparkSession
#
# Esta célula inicializa a `SparkSession`, que é o ponto de entrada para programar Spark com a API DataFrame e Dataset. Ela define o nome da aplicação Spark.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

spark = (
    SparkSession.builder
        .appName("PNAD_COVID_Traducao_09")
        .getOrCreate()
)

# %% [markdown]
# ### Definição dos Caminhos dos Arquivos
#
# Esta célula define os caminhos para os arquivos de entrada:
# - `micro_09_path`: Caminho para o arquivo CSV contendo os microdados da PNAD COVID de setembro de 2020.
# - `micro_10_path`: Caminho para o arquivo CSV contendo os microdados da PNAD COVID de outubro de 2020.
# - `micro_11_path`: Caminho para o arquivo CSV contendo os microdados da PNAD COVID de novembro de 2020.
# - `dic_path_09`: Caminho para o arquivo Excel (.xls) que contém o dicionário de variáveis dos microdados.
# - `dic_path_10`: Caminho para o arquivo Excel (.xls) que contém o dicionário de variáveis dos microdados.
# - `dic_path_11`: Caminho para o arquivo Excel (.xls) que contém o dicionário de variáveis dos microdados.

# %%
# Caminho do microdados (CSV)
micro_09_path = "s3://lab-746762238259/data-input/microdados/PNAD_COVID_092020.csv"
micro_10_path = "s3://lab-746762238259/data-input/microdados/PNAD_COVID_102020.csv"
micro_11_path = "s3://lab-746762238259/data-input/microdados/PNAD_COVID_112020.csv"

# %% [markdown]
# ### Carregamento dos Microdados CSV
#
# Descrição:
# Carrega os arquivos CSV de microdados de cada mês em DataFrames do Spark, exibindo o número de colunas e as primeiras linhas para verificação.

# %%
micro_09 = (
    spark.read.csv(micro_09_path, header=True, inferSchema=True, sep=",")
)

print("Microdados colunas:", len(micro_09.columns))
micro_09.show(5, truncate=False)

micro_10 = (
    spark.read.csv(micro_10_path, header=True, inferSchema=True, sep=",")
)

print("Microdados colunas:", len(micro_10.columns))
micro_10.show(5, truncate=False)

micro_11 = (
    spark.read.csv(micro_11_path, header=True, inferSchema=True, sep=",")
)

print("Microdados colunas:", len(micro_11.columns))
micro_11.show(5, truncate=False)
# Out:
# Microdados colunas: 145
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |Ano |UF |CAPITAL|RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022|V1023|V1030 |V1031       |V1032       |posest|A001|A001A|A001B1|A001B2|A001B3|A002|A003|A004|A005|A006|A007|A008|A009|B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011|C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007|C007A|C007B|C007C|C007D|C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010|C0101|C01011|C01012|C0102|C01021|C01022|C0103|C0104|C011A|C011A1|C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016|C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001|E0021|E0022|E0023|E0024|F001|F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061|F006|
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |152677|133.93337786|164.20936068|1114  |1   |1    |5     |8     |1984  |36  |1   |4   |5   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |4   |null |1    |35   |6    |null |null  |null  |null |48  |48  |null |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |150642|133.93337786|166.94461021|1124  |2   |2    |18    |8     |1990  |30  |2   |4   |7   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |7   |null |null |27   |20   |null |null  |null  |null |36  |36  |2    |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|2   |null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |145237|133.93337786|171.88775372|1112  |3   |4    |25    |12    |2006  |13  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |145237|133.93337786|171.88775372|1112  |4   |4    |24    |8     |2009  |11  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |2    |1    |9    |5    |1110011|110015970|1    |1    |91889 |133.93337786|127.53668218|1126  |1   |1    |18    |5     |1963  |57  |2   |1   |2   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |2   |2   |null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|2   |2   |1   |1    |2    |null |2    |null |2    |null |1    |1045 |2    |null |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# only showing top 5 rows
#
# Microdados colunas: 145
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |Ano |UF |CAPITAL|RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022|V1023|V1030 |V1031       |V1032       |posest|A001|A001A|A001B1|A001B2|A001B3|A002|A003|A004|A005|A006|A007|A008|A009|B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011|C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007|C007A|C007B|C007C|C007D|C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010|C0101|C01011|C01012|C0102|C01021|C01022|C0103|C0104|C011A|C011A1|C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016|C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001|E0021|E0022|E0023|E0024|F001|F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061|F006|
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |2020|11 |11     |null   |1    |4    |10   |6    |1110011|110015970|1    |1    |152790|122.75397639|143.7459631 |1114  |1   |1    |5     |8     |1984  |36  |1   |4   |5   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |4   |null |1    |35   |6    |null |null  |null  |null |48  |48  |null |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |10   |6    |1110011|110015970|1    |1    |150739|122.75397639|148.52050973|1124  |2   |2    |18    |8     |1990  |30  |2   |4   |7   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |7   |null |null |27   |20   |null |null  |null  |null |36  |36  |2    |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|2   |null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |10   |6    |1110011|110015970|1    |1    |144993|122.75397639|158.31081955|1112  |3   |4    |25    |12    |2006  |13  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |10   |6    |1110011|110015970|1    |1    |144993|122.75397639|158.31081955|1112  |4   |4    |24    |8     |2009  |11  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |2    |1    |10   |6    |1110011|110015970|1    |1    |92130 |122.75397639|123.6186403 |1126  |1   |1    |18    |5     |1963  |57  |2   |1   |2   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |3   |2   |2   |null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|2   |2   |1   |1    |2    |null |2    |null |2    |null |1    |1045 |2    |null |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# only showing top 5 rows
#
# Microdados colunas: 148
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+-----+-----+----+-----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |Ano |UF |CAPITAL|RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022|V1023|V1030 |V1031       |V1032       |posest|A001|A001A|A001B1|A001B2|A001B3|A002|A003|A004|A005|A006|A006A|A006B|A007|A007A|A008|A009|B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011|C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007|C007A|C007B|C007C|C007D|C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010|C0101|C01011|C01012|C0102|C01021|C01022|C0103|C0104|C011A|C011A1|C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016|C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001|E0021|E0022|E0023|E0024|F001|F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061|F006|
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+-----+-----+----+-----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# |2020|11 |11     |null   |1    |4    |11   |7    |1110011|110015970|1    |1    |152902|101.01170275|117.46371855|1114  |1   |1    |5     |8     |1984  |36  |1   |4   |5   |null|null |null |null|null |null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |4   |null |1    |35   |6    |null |null  |null  |null |48  |48  |null |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |600  |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |11   |7    |1110011|110015970|1    |1    |150835|101.01170275|125.75120197|1124  |2   |2    |18    |8     |1990  |30  |2   |4   |7   |null|null |null |null|null |null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |7   |null |null |27   |20   |null |null  |null  |null |36  |36  |2    |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|2   |null|null|null |2    |null |2    |null |2    |null |2    |null |1    |600  |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |11   |7    |1110011|110015970|1    |1    |144737|101.01170275|131.36101755|1112  |3   |4    |25    |12    |2006  |13  |1   |4   |2   |1   |1    |3    |1   |null |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |600  |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |1    |4    |11   |7    |1110011|110015970|1    |1    |144737|101.01170275|131.36101755|1112  |4   |4    |24    |8     |2009  |11  |1   |4   |2   |1   |1    |3    |1   |null |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |600  |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# |2020|11 |11     |null   |2    |1    |11   |7    |1110011|110015970|1    |1    |92377 |101.01170275|100.73351653|1126  |1   |1    |18    |5     |1963  |57  |2   |1   |2   |null|null |null |null|null |null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |2   |2   |null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|2   |2   |1   |1    |2    |null |2    |null |2    |null |1    |1045 |2    |null |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+-----+-----+----+-----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+
# only showing top 5 rows

# %% [markdown]
# ### Unificação dos Microdados
# Esta célula unifica os três DataFrames (setembro, outubro e novembro) em um único DataFrame, permitindo a análise consolidada dos três meses. A função unionByName é usada para unir por nome de coluna, permitindo colunas ausentes.

# %%
from functools import reduce

micro_09 = spark.read.csv(micro_09_path, header=True, inferSchema=True)
micro_10 = spark.read.csv(micro_10_path, header=True, inferSchema=True)
micro_11 = spark.read.csv(micro_11_path, header=True, inferSchema=True)

dfs = [micro_09, micro_10, micro_11]

micro_unificado = reduce(
    lambda df1, df2: df1.unionByName(df2, allowMissingColumns=True),
    dfs
)

micro_unificado.show(5, truncate=False)
# Out:
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+-----+-----+-----+
# |Ano |UF |CAPITAL|RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022|V1023|V1030 |V1031       |V1032       |posest|A001|A001A|A001B1|A001B2|A001B3|A002|A003|A004|A005|A006|A007|A008|A009|B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011|C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007|C007A|C007B|C007C|C007D|C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010|C0101|C01011|C01012|C0102|C01021|C01022|C0103|C0104|C011A|C011A1|C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016|C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001|E0021|E0022|E0023|E0024|F001|F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061|F006|A006A|A006B|A007A|
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+-----+-----+-----+
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |152677|133.93337786|164.20936068|1114  |1   |1    |5     |8     |1984  |36  |1   |4   |5   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |4   |null |1    |35   |6    |null |null  |null  |null |48  |48  |null |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |null |null |null |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |150642|133.93337786|166.94461021|1124  |2   |2    |18    |8     |1990  |30  |2   |4   |7   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |1   |null|null|null|null|null |null |null |2   |7   |null |null |27   |20   |null |null  |null  |null |36  |36  |2    |1   |1    |4     |1045  |null |null  |null  |null |null |1    |1     |4      |1045   |null  |null   |null   |1   |null|2   |null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |null |null |null |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |145237|133.93337786|171.88775372|1112  |3   |4    |25    |12    |2006  |13  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |null |null |null |
# |2020|11 |11     |null   |1    |4    |9    |5    |1110011|110015970|1    |1    |145237|133.93337786|171.88775372|1112  |4   |4    |24    |8     |2009  |11  |1   |4   |2   |1   |1   |5   |3   |2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|1   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |4   |null|null|null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|null|null|null|null |2    |null |2    |null |2    |null |2    |null |1    |1200 |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |null |null |null |
# |2020|11 |11     |null   |2    |1    |9    |5    |1110011|110015970|1    |1    |91889 |133.93337786|127.53668218|1126  |1   |1    |18    |5     |1963  |57  |2   |1   |2   |null|null|null|null|2    |2    |2    |2    |2    |2    |2    |2    |2    |2     |2     |2     |2     |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|2   |2   |null |null |null |null |null |null |2    |2    |2    |2    |2    |2    |2   |2   |2   |null|null|null|null |null |null |null|null|null |null |null |null |null |null  |null  |null |null|null|null |null|null |null  |null  |null |null  |null  |null |null |null |null  |null   |null   |null  |null   |null   |null|null|2   |2   |1   |1    |2    |null |2    |null |2    |null |1    |1045 |2    |null |2    |null |2    |null |3   |null |null |null |null |1   |null |null |1     |1     |1     |2     |1     |1    |1   |null |null |null |
# +----+---+-------+-------+-----+-----+-----+-----+-------+---------+-----+-----+------+------------+------------+------+----+-----+------+------+------+----+----+----+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+----+----+-----+-----+-----+----+----+-----+-----+-----+-----+-----+------+------+-----+----+----+-----+----+-----+------+------+-----+------+------+-----+-----+-----+------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+-----+-----+-----+-----+----+-----+-----+------+------+------+------+------+-----+----+-----+-----+-----+
# only showing top 5 rows

# %% [markdown]
# ### Conversão do Dicionário Excel para CSV
#
# O dicionário original está em formato Excel. Esta célula:
# 1.  Lê o arquivo Excel para um DataFrame Pandas.
# 2.  Salva o DataFrame Pandas em um arquivo CSV temporário (`/content/dicionario_pnad.csv`).
#
# Esta etapa é necessária para que o Spark possa ler o dicionário de forma mais fácil e consistente.

# %%
import pandas as pd

# Caminho do dicionário (CSV)
dic_path_09 = "s3://lab-746762238259/data-input/dicionários/Dicionario_PNAD_COVID_092020_20220621.csv"
dic_path_10 = "s3://lab-746762238259/data-input/dicionários/Dicionario_PNAD_COVID_102020_20220621.csv"
dic_path_11 = "s3://lab-746762238259/data-input/dicionários/Dicionario_PNAD_COVID_112020_20220621.csv"

dic_excel_paths = {
    "09": dic_path_09,
    "10": dic_path_10,
    "11": dic_path_11
}

dic_csv_paths = []

for mes, path in dic_excel_paths.items():
    df_pd = pd.read_csv(path, header=None)

    csv_path = f"s3://lab-746762238259/data-input/dicionários/dicionario_pnad_{mes}.csv"
    df_pd.to_csv(csv_path, index=False, header=False)

    dic_csv_paths.append(csv_path)

# %% [markdown]
# ### Carregamento do Dicionário no Spark
#
# Descrição:
# Carrega os arquivos CSV do dicionário convertidos em um DataFrame do Spark, atribuindo nomes genéricos às colunas (A, B, C, D, E, F).
#
# Esta etapa é necessária para que o Spark possa ler o dicionário de forma mais fácil e consistente.

# %%
df_dict_raw = (
    spark.read.format("csv")
    .option("header", "false")
    .option("sep", ",")
    .load(dic_csv_paths)
)

df_dict = df_dict_raw.toDF("A", "B", "C", "D", "E", "F")
df_dict.show(20, truncate=False)
# Out:
# +--------------------------------------+-------+----+--------------------+-----+-------------------+
# |A                                     |B      |C   |D                   |E    |F                  |
# +--------------------------------------+-------+----+--------------------+-----+-------------------+
# |Dicionário das variáveis da PNAD COVID|null   |null|null                |null |null               |
# |Tamanho                               |Código |null|null                |null |null               |
# |da                                    |null   |null|null                |null |null               |
# |variável"                             |Quesito|null|Categorias          |null |null               |
# |null                                  |null   |nº  |Descrição           |Tipo |Descrição          |
# |Parte 1 - Identificação e Controle    |null   |null|null                |null |null               |
# |4                                     |Ano    |null|Ano de referência   |null |null               |
# |2                                     |UF     |null|Unidade da Federação|11   |Rondônia           |
# |null                                  |null   |null|null                |12   |Acre               |
# |null                                  |null   |null|null                |13   |Amazonas           |
# |null                                  |null   |null|null                |14   |Roraima            |
# |null                                  |null   |null|null                |15   |Pará               |
# |null                                  |null   |null|null                |16   |Amapá              |
# |null                                  |null   |null|null                |17   |Tocantins          |
# |null                                  |null   |null|null                |21   |Maranhão           |
# |null                                  |null   |null|null                |22   |Piauí              |
# |null                                  |null   |null|null                |23   |Ceará              |
# |null                                  |null   |null|null                |24   |Rio Grande do Norte|
# |null                                  |null   |null|null                |25   |Paraíba            |
# |null                                  |null   |null|null                |26   |Pernambuco         |
# +--------------------------------------+-------+----+--------------------+-----+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Identificação de Linhas de Variáveis
#
# Descrição:
# Cria uma coluna is_var para identificar quais linhas do dicionário contêm informações sobre variáveis (códigos e descrições), baseando-se na presença de valores nas colunas B, D e E.

# %%
df_dict = df_dict.withColumn(
    "is_var",
    (F.col("B").isNotNull()) &
    (F.length("B") > 0) &
    (F.col("D").isNotNull()) &
    (F.length("D") > 0) &
    (F.col("E").isNotNull()) &
    (F.length("E") > 0)
)

# %% [markdown]
# ### Visualização das Linhas do Dicionário
#
# Descrição:
# Exibe as colunas relevantes do dicionário junto com a flag is_var para verificação visual da identificação correta das variáveis.

# %%
df_dict.select("B","D","E","F","is_var").show(50, truncate=False)
# Out:
# +-------+--------------------+-----+-----------------------------+------+
# |B      |D                   |E    |F                            |is_var|
# +-------+--------------------+-----+-----------------------------+------+
# |null   |null                |null |null                         |false |
# |Código |null                |null |null                         |false |
# |null   |null                |null |null                         |false |
# |Quesito|Categorias          |null |null                         |false |
# |null   |Descrição           |Tipo |Descrição                    |false |
# |null   |null                |null |null                         |false |
# |Ano    |Ano de referência   |null |null                         |false |
# |UF     |Unidade da Federação|11   |Rondônia                     |true  |
# |null   |null                |12   |Acre                         |false |
# |null   |null                |13   |Amazonas                     |false |
# |null   |null                |14   |Roraima                      |false |
# |null   |null                |15   |Pará                         |false |
# |null   |null                |16   |Amapá                        |false |
# |null   |null                |17   |Tocantins                    |false |
# |null   |null                |21   |Maranhão                     |false |
# |null   |null                |22   |Piauí                        |false |
# |null   |null                |23   |Ceará                        |false |
# |null   |null                |24   |Rio Grande do Norte          |false |
# |null   |null                |25   |Paraíba                      |false |
# |null   |null                |26   |Pernambuco                   |false |
# |null   |null                |27   |Alagoas                      |false |
# |null   |null                |28   |Sergipe                      |false |
# |null   |null                |29   |Bahia                        |false |
# |null   |null                |31   |Minas Gerais                 |false |
# |null   |null                |32   |Espírito Santo               |false |
# |null   |null                |33   |Rio de Janeiro               |false |
# |null   |null                |35   |São Paulo                    |false |
# |null   |null                |41   |Paraná                       |false |
# |null   |null                |42   |Santa Catarina               |false |
# |null   |null                |43   |Rio Grande do Sul            |false |
# |null   |null                |50   |Mato Grosso do Sul           |false |
# |null   |null                |51   |Mato Grosso                  |false |
# |null   |null                |52   |Goiás                        |false |
# |null   |null                |53   |Distrito Federal             |false |
# |CAPITAL|Capital             |11   |Município de Porto Velho (RO)|true  |
# |null   |null                |12   |Município de Rio Branco (AC) |false |
# |null   |null                |13   |Município de Manaus (AM)     |false |
# |null   |null                |14   |Município de Boa Vista (RR)  |false |
# |null   |null                |15   |Município de Belém (PA)      |false |
# |null   |null                |16   |Município de Macapá (AP)     |false |
# |null   |null                |17   |Município de Palmas (TO)     |false |
# |null   |null                |21   |Município de São Luís (MA)   |false |
# |null   |null                |22   |Município de Teresina (PI)   |false |
# |null   |null                |23   |Município de Fortaleza (CE)  |false |
# |null   |null                |24   |Município de Natal (RN)      |false |
# |null   |null                |25   |Município de João Pessoa (PB)|false |
# |null   |null                |26   |Município de Recife (PE)     |false |
# |null   |null                |27   |Município de Maceió (AL)     |false |
# |null   |null                |28   |Município de Aracaju (SE)    |false |
# |null   |null                |29   |Município de Salvador (BA)   |false |
# +-------+--------------------+-----+-----------------------------+------+
# only showing top 50 rows

# %% [markdown]
# ### Construção das Dimensões (DIMs)
#
# Descrição:
# Processa o dicionário para extrair tabelas de dimensão (DIMs) para cada variável presente nos microdados. O processo inclui:
#
# Identificação de blocos de variáveis
#
# Extração do nome e descrição de cada variável
#
# Criação de DataFrames de dimensão com códigos e descrições
#
# Filtragem para incluir apenas variáveis presentes nos microdados

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# =====================================================
# 1. Criar identificador de bloco (cada variável)
# =====================================================
w = Window.orderBy(F.monotonically_increasing_id())

df_blocos = (
    df_dict
    .withColumn(
        "bloco_id",
        F.sum(F.when(F.col("is_var") == True, 1).otherwise(0)).over(w)
    )
)

# =====================================================
# 2. Criar tabela auxiliar com o nome da variável por bloco
# =====================================================
df_vars = (
    df_blocos
    .filter(F.col("is_var") == True)
    .select(
        F.col("bloco_id"),
        F.col("B").alias("nome_variavel"),
        F.col("D").alias("descricao_variavel")
    )
)

# =====================================================
# 3. Anexar o nome da variável a todas as linhas do bloco
# =====================================================
df_dict_norm = (
    df_blocos
    .join(df_vars, on="bloco_id", how="left")
)

# =====================================================
# 4. Função para criar DIM de uma variável
# =====================================================


def criar_dim(df_dict_norm, nome_var):
    return (
        df_dict_norm
        .filter(
            (F.col("nome_variavel") == nome_var) &
            (F.col("E").rlike(r"^\d+$"))   # <-- REMOVE is_var == False
        )
        .select(
            F.col("E").cast("int").alias(f"{nome_var}_codigo"),
            F.col("F").alias(f"{nome_var}_descricao")
        )
        .dropDuplicates()
        .orderBy(f"{nome_var}_codigo")
    )

# =====================================================
# 5. Descobrir variáveis que existem no microdados
# =====================================================
todas_vars = [
    r["nome_variavel"]
    for r in df_vars.select("nome_variavel").distinct().collect()
    if r["nome_variavel"] not in (None, "")
]

variaveis_no_micro = [v for v in todas_vars if v in micro_unificado.columns]

print("Variáveis presentes no micro_09:")
print(variaveis_no_micro)

# =====================================================
# 6. Criar DIMS
# =====================================================
dims = {}

for var in variaveis_no_micro:
    print(f"\n🔹 Construindo DIM para {var}")
    dim = criar_dim(df_dict_norm, var)
    dims[var] = dim
    dim.show(20, truncate=False)
# Out:
# Variáveis presentes no micro_09:
# ['A001B1', 'B0015', 'B0019', 'B00111', 'B0034', 'B0045', 'C005', 'C009', 'A009', 'C004', 'C01022', 'C012', 'C013', 'D0043', 'F002A4', 'B0031', 'B0033', 'B0041', 'B009A', 'B009E', 'B0101', 'B0106', 'C003', 'C0052', 'C007E1', 'C008', 'C0104', 'C011A22', 'F0022', 'UPA', 'V1022', 'B0017', 'B0036', 'B0104', 'C007D', 'C01021', 'C011A21', 'E0023', 'F001', 'F0061', 'V1012', 'Estrato', 'A005', 'B0012', 'B00113', 'B009C', 'C001', 'C014', 'E001', 'F006', 'UF', 'V1008', 'C007C', 'C007E', 'C007E2', 'C01012', 'C011A1', 'C015', 'F002A3', 'CAPITAL', 'V1032', 'A003', 'B009D', 'B009F', 'C007A', 'D0031', 'D0041', 'A002', 'A006', 'B00110', 'B009B', 'B0103', 'C0051', 'C0053', 'D0033', 'B0013', 'B0014', 'B002', 'B005', 'C007F', 'C01011', 'C011A2', 'D0061', 'E0024', 'V1016', 'A004', 'B0011', 'B0037', 'B0044', 'C002', 'C011A12', 'C016', 'D0021', 'D0023', 'F0021', 'V1013', 'A001', 'A007', 'B0018', 'B0035', 'B0042', 'B007', 'C006', 'F002A1', 'V1031', 'B0032', 'B0043', 'B0046', 'B0102', 'C011A', 'C017A', 'D0073', 'F002A2', 'A001A', 'B006', 'B0105', 'B011', 'C007', 'D0011', 'F002A5', 'A001B2', 'A008', 'B00112', 'C0103', 'C011A11', 'D0051', 'D0071', 'E0022', 'V1023', 'B008', 'C009A', 'C0101', 'C0102', 'D0053', 'A001B3', 'B0016', 'C007B', 'C010', 'D0013', 'D0063', 'E0021', 'A007A', 'A006A', 'A006B']
#
# 🔹 Construindo DIM para A001B1
# +-------------+----------------+
# |A001B1_codigo|A001B1_descricao|
# +-------------+----------------+
# |99           |Não informado   |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B0015
# +------------+---------------+
# |B0015_codigo|B0015_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0019
# +------------+---------------+
# |B0019_codigo|B0019_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B00111
# +-------------+----------------+
# |B00111_codigo|B00111_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# |9            |Ignorado        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B0034
# +------------+---------------+
# |B0034_codigo|B0034_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0045
# +------------+---------------+
# |B0045_codigo|B0045_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C005
# +-----------+--------------------------+
# |C005_codigo|C005_descricao            |
# +-----------+--------------------------+
# |1          |Menos de 1 mês            |
# |2          |De 1 mês a menos de 1 ano |
# |3          |De 1 ano a menos de 2 anos|
# |4          |2 anos ou mais            |
# +-----------+--------------------------+
#
#
# 🔹 Construindo DIM para C009
# +-----------+--------------+
# |C009_codigo|C009_descricao|
# +-----------+--------------+
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para A009
# +-----------+-----------------------------+
# |A009_codigo|A009_descricao               |
# +-----------+-----------------------------+
# |1          |Menos de 1 hora              |
# |2          |De 1 hora a menos de 2 horas |
# |3          |De 2 horas a menos de 5 horas|
# |4          |5 horas ou mais              |
# +-----------+-----------------------------+
#
#
# 🔹 Construindo DIM para C004
# +-----------+--------------------------------+
# |C004_codigo|C004_descricao                  |
# +-----------+--------------------------------+
# |1          |Sim                             |
# |2          |Não                             |
# |3          |O trabalho já não era remunerado|
# +-----------+--------------------------------+
#
#
# 🔹 Construindo DIM para C01022
# +-------------+----------------+
# |C01022_codigo|C01022_descricao|
# +-------------+----------------+
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C012
# +-----------+--------------+
# |C012_codigo|C012_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C013
# +-----------+--------------+
# |C013_codigo|C013_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para D0043
# +------------+---------------+
# |D0043_codigo|D0043_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para F002A4
# +-------------+----------------+
# |F002A4_codigo|F002A4_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B0031
# +------------+---------------+
# |B0031_codigo|B0031_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0033
# +------------+---------------+
# |B0033_codigo|B0033_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0041
# +------------+---------------+
# |B0041_codigo|B0041_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B009A
# +------------+---------------+
# |B009A_codigo|B009A_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B009E
# +------------+---------------+
# |B009E_codigo|B009E_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0101
# +------------+---------------+
# |B0101_codigo|B0101_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0106
# +------------+---------------+
# |B0106_codigo|B0106_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C003
# +-----------+-------------------------------------------------------------------------------------------------------------------------------------+
# |C003_codigo|C003_descricao                                                                                                                       |
# +-----------+-------------------------------------------------------------------------------------------------------------------------------------+
# |1          |Estava em quarentena, isolamento, distanciamento social ou férias coletivas                                                          |
# |2          |Férias, folga ou jornada de trabalho variável                                                                                        |
# |3          |Licença maternidade ou paternidade                                                                                                   |
# |4          |Licença remunerada por motivo de saúde ou acidente da própria pessoa                                                                 |
# |5          |Outro tipo de licença remunerada (estudo, paternidade, casamento, licença prêmio, etc.)                                              |
# |6          |Afastamento do próprio negócio/empresa por motivo de gestação, saúde, acidente, etc., sem ser remunerado por instituto de previdência|
# |7          |Fatores ocasionais (mau tempo, paralisação nos serviços de transportes, etc.)                                                        |
# |8          |Outro motivo                                                                                                                         |
# +-----------+-------------------------------------------------------------------------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para C0052
# +------------+---------------+
# |C0052_codigo|C0052_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C007E1
# +-------------+----------------+
# |C007E1_codigo|C007E1_descricao|
# +-------------+----------------+
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C008
# +-----------+--------------+
# |C008_codigo|C008_descricao|
# +-----------+--------------+
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C0104
# +------------+---------------+
# |C0104_codigo|C0104_descricao|
# +------------+---------------+
# |4           |Não remunerado |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C011A22
# +--------------+-----------------+
# |C011A22_codigo|C011A22_descricao|
# +--------------+-----------------+
# +--------------+-----------------+
#
#
# 🔹 Construindo DIM para F0022
# +------------+----------------+
# |F0022_codigo|F0022_descricao |
# +------------+----------------+
# |0           |1 - 100         |
# |88          |Aluguel a vencer|
# +------------+----------------+
#
#
# 🔹 Construindo DIM para UPA
# +----------+-------------+
# |UPA_codigo|UPA_descricao|
# +----------+-------------+
# +----------+-------------+
#
#
# 🔹 Construindo DIM para V1022
# +------------+---------------+
# |V1022_codigo|V1022_descricao|
# +------------+---------------+
# |1           |Urbana         |
# |2           |Rural          |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0017
# +------------+---------------+
# |B0017_codigo|B0017_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0036
# +------------+---------------+
# |B0036_codigo|B0036_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0104
# +------------+---------------+
# |B0104_codigo|B0104_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C007D
# +------------+------------------------------------------------------------------------------------------------------------------+
# |C007D_codigo|C007D_descricao                                                                                                   |
# +------------+------------------------------------------------------------------------------------------------------------------+
# |1           |Agricultura, pecuária, produção florestal e pesca                                                                 |
# |2           |Extração de petróleo, carvão mineral, minerais metálicos, pedra, areia, sal etc.                                  |
# |3           |Indústria da transformação (inclusive confecção e fabricação caseira)                                             |
# |4           |Fornecimento de eletricidade e gás, água, esgoto e coleta de lixo                                                 |
# |5           |Construção                                                                                                        |
# |6           |Comércio no atacado e varejo;                                                                                     |
# |7           |Reparação de veículos automotores e motocicletas                                                                  |
# |8           |Transporte de passageiros                                                                                         |
# |9           |Transporte de mercadorias                                                                                         |
# |10          |Armazenamento, correios e serviços de entregas                                                                    |
# |11          |Hospedagem (hotéis, pousadas etc.)                                                                                |
# |12          |Serviço de alimentação (bares, restaurantes, ambulantes de alimentação)                                           |
# |13          |Informação e comunicação (jornais, rádio e televisão, telecomunicações e informática)                             |
# |14          |Bancos, atividades financeiras e de seguros                                                                       |
# |15          |Atividades imobiliárias                                                                                           |
# |16          |Escritórios de advocacia, engenharia, publicidade e veterinária (Atividades profissionais, científicas e técnicas)|
# |17          |Atividades de locação de mão de obra, segurança, limpeza, paisagismo e teleatendimento                            |
# |18          |Administração pública (governo federal, estadual e municipal)                                                     |
# |19          |Educação                                                                                                          |
# |20          |Saúde humana e assistência social                                                                                 |
# +------------+------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
#
# 🔹 Construindo DIM para C01021
# +-------------+----------------+
# |C01021_codigo|C01021_descricao|
# +-------------+----------------+
# |0            |0 - 100         |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C011A21
# +--------------+-----------------+
# |C011A21_codigo|C011A21_descricao|
# +--------------+-----------------+
# |0             |0 - 100          |
# +--------------+-----------------+
#
#
# 🔹 Construindo DIM para E0023
# +------------+---------------+
# |E0023_codigo|E0023_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para F001
# +-----------+-----------------------+
# |F001_codigo|F001_descricao         |
# +-----------+-----------------------+
# |1          |Próprio - já pago      |
# |2          |Próprio - ainda pagando|
# |3          |Alugado                |
# |4          |Cedido por empregador  |
# |5          |Cedido por familiar    |
# |6          |Cedido de outra forma  |
# |7          |Outra condição         |
# +-----------+-----------------------+
#
#
# 🔹 Construindo DIM para F0061
# +------------+-------------------+
# |F0061_codigo|F0061_descricao    |
# +------------+-------------------+
# |1           |Pessoa moradora    |
# |2           |Pessoa não moradora|
# |9           |Ignorado           |
# +------------+-------------------+
#
#
# 🔹 Construindo DIM para V1012
# +------------+---------------+
# |V1012_codigo|V1012_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para Estrato
# +--------------+-----------------+
# |Estrato_codigo|Estrato_descricao|
# +--------------+-----------------+
# +--------------+-----------------+
#
#
# 🔹 Construindo DIM para A005
# +-----------+------------------------------------+
# |A005_codigo|A005_descricao                      |
# +-----------+------------------------------------+
# |1          |Sem instrução                       |
# |2          |Fundamental incompleto              |
# |3          |Fundamental completa                |
# |4          |Médio incompleto                    |
# |5          |Médio completo                      |
# |6          |Superior incompleto                 |
# |7          |Superior completo                   |
# |8          |Pós-graduação, mestrado ou doutorado|
# +-----------+------------------------------------+
#
#
# 🔹 Construindo DIM para B0012
# +------------+---------------+
# |B0012_codigo|B0012_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B00113
# +-------------+----------------+
# |B00113_codigo|B00113_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# |9            |Ignorado        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B009C
# +------------+---------------+
# |B009C_codigo|B009C_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C001
# +-----------+--------------+
# |C001_codigo|C001_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C014
# +-----------+--------------+
# |C014_codigo|C014_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para E001
# +-----------+---------------------------------------+
# |E001_codigo|E001_descricao                         |
# +-----------+---------------------------------------+
# |1          |Sim, e pelo menos um morador conseguiu |
# |2          |Sim, mas nenhum morador conseguiu      |
# |3          |Não solicitou                          |
# +-----------+---------------------------------------+
#
#
# 🔹 Construindo DIM para F006
# +-----------+--------------+
# |F006_codigo|F006_descricao|
# +-----------+--------------+
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para UF
# +---------+-------------------+
# |UF_codigo|UF_descricao       |
# +---------+-------------------+
# |11       |Rondônia           |
# |12       |Acre               |
# |13       |Amazonas           |
# |14       |Roraima            |
# |15       |Pará               |
# |16       |Amapá              |
# |17       |Tocantins          |
# |21       |Maranhão           |
# |22       |Piauí              |
# |23       |Ceará              |
# |24       |Rio Grande do Norte|
# |25       |Paraíba            |
# |26       |Pernambuco         |
# |27       |Alagoas            |
# |28       |Sergipe            |
# |29       |Bahia              |
# |31       |Minas Gerais       |
# |32       |Espírito Santo     |
# |33       |Rio de Janeiro     |
# |35       |São Paulo          |
# +---------+-------------------+
# only showing top 20 rows
#
#
# 🔹 Construindo DIM para V1008
# +------------+---------------+
# |V1008_codigo|V1008_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C007C
# +------------+-----------------------------------------------------------------------------------------------+
# |C007C_codigo|C007C_descricao                                                                                |
# +------------+-----------------------------------------------------------------------------------------------+
# |1           |Empregado doméstico, diarista, cozinheiro (em domicílios particulares),                        |
# |2           |Faxineiro, auxiliar de limpeza etc. (em empresa pública ou privada),                           |
# |3           |Auxiliar de escritório, escriturário                                                           |
# |4           |Secretária, recepcionista                                                                      |
# |5           |Operador de Telemarketing                                                                      |
# |6           |Comerciante (dono do bar, da loja etc.)                                                        |
# |7           |Balconista, vendedor de loja                                                                   |
# |8           |Vendedor a domicílio, representante de vendas, vendedor de catálogo (Avon, Natura etc.)        |
# |9           |Vendedor ambulante (feirante, camelô, comerciante de rua, quiosque)                            |
# |10          |Cozinheiro e garçom (de restaurantes, empresas)                                                |
# |11          |Padeiro, açougueiro e doceiro                                                                  |
# |12          |Agricultor, criador de animais, pescador, silvicultor e jardineiro                             |
# |13          |Auxiliar da agropecuária (colhedor de frutas, boia fria, etc.)                                 |
# |14          |Motorista (de aplicativo, de taxi, de van, de mototáxi, de ônibus)                             |
# |15          |Motorista de caminhão (caminhoneiro),                                                          |
# |16          |Motoboy,                                                                                       |
# |17          |Entregador de mercadorias (de restaurante, de farmácia, de loja, Uber Eats, IFood, Rappy etc.) |
# |18          |Pedreiro, servente de pedreiro, pintor, eletricista, marceneiro                                |
# |19          |Mecânico de veículos, máquinas industriais etc.                                                |
# |20          |Artesão, costureiro e sapateiro                                                                |
# +------------+-----------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
#
# 🔹 Construindo DIM para C007E
# +------------+---------------------+
# |C007E_codigo|C007E_descricao      |
# +------------+---------------------+
# |1           |1 a 5 empregados     |
# |2           |6 a 10 empregados    |
# |3           |11 ou mais empregados|
# +------------+---------------------+
#
#
# 🔹 Construindo DIM para C007E2
# +-------------+----------------+
# |C007E2_codigo|C007E2_descricao|
# +-------------+----------------+
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C01012
# +-------------+----------------+
# |C01012_codigo|C01012_descricao|
# +-------------+----------------+
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C011A1
# +-------------+----------------+
# |C011A1_codigo|C011A1_descricao|
# +-------------+----------------+
# |1            |Em dinheiro     |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C015
# +-----------+--------------+
# |C015_codigo|C015_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para F002A3
# +-------------+----------------+
# |F002A3_codigo|F002A3_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para CAPITAL
# +--------------+----------------------------------------+
# |CAPITAL_codigo|CAPITAL_descricao                       |
# +--------------+----------------------------------------+
# |11            |Município de Porto Velho (RO)           |
# |12            |Município de Rio Branco (AC)            |
# |13            |Município de Manaus (AM)                |
# |14            |Município de Boa Vista (RR)             |
# |15            |Município de Belém (PA)                 |
# |15            |Região Metropolitana de Belém (PA)      |
# |16            |Município de Macapá (AP)                |
# |16            |Região Metropolitana de Macapá (AP)     |
# |17            |Município de Palmas (TO)                |
# |21            |Município de São Luís (MA)              |
# |21            |Região Metropolitana de Grande São      |
# |22            |Município de Teresina (PI)              |
# |22            |Região Administrativa Integrada         |
# |23            |Região Metropolitana de Fortaleza (CE)  |
# |23            |Município de Fortaleza (CE)             |
# |24            |Município de Natal (RN)                 |
# |24            |Região Metropolitana de Natal (RN)      |
# |25            |Município de João Pessoa (PB)           |
# |25            |Região Metropolitana de João Pessoa (PB)|
# |26            |Município de Recife (PE)                |
# +--------------+----------------------------------------+
# only showing top 20 rows
#
#
# 🔹 Construindo DIM para V1032
# +------------+---------------+
# |V1032_codigo|V1032_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A003
# +-----------+--------------+
# |A003_codigo|A003_descricao|
# +-----------+--------------+
# |1          |Homem         |
# |2          |Mulher        |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B009D
# +------------+-----------------------------+
# |B009D_codigo|B009D_descricao              |
# +------------+-----------------------------+
# |1           |Positivo                     |
# |2           |Negativo                     |
# |3           |Inconclusivo                 |
# |4           |Ainda não recebeu o resultado|
# |9           |Ignorado                     |
# +------------+-----------------------------+
#
#
# 🔹 Construindo DIM para B009F
# +------------+-----------------------------+
# |B009F_codigo|B009F_descricao              |
# +------------+-----------------------------+
# |1           |Positivo                     |
# |2           |Negativo                     |
# |3           |Inconclusivo                 |
# |4           |Ainda não recebeu o resultado|
# |9           |Ignorado                     |
# +------------+-----------------------------+
#
#
# 🔹 Construindo DIM para C007A
# +------------+---------------+
# |C007A_codigo|C007A_descricao|
# +------------+---------------+
# |1           |Federal        |
# |2           |Estadual       |
# |3           |Municipal      |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0031
# +------------+---------------+
# |D0031_codigo|D0031_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0041
# +------------+---------------+
# |D0041_codigo|D0041_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A002
# +-----------+--------------+
# |A002_codigo|A002_descricao|
# +-----------+--------------+
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para A006
# +-----------+--------------+
# |A006_codigo|A006_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B00110
# +-------------+----------------+
# |B00110_codigo|B00110_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# |9            |Ignorado        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B009B
# +------------+-----------------------------+
# |B009B_codigo|B009B_descricao              |
# +------------+-----------------------------+
# |1           |Positivo                     |
# |2           |Negativo                     |
# |3           |Inconclusivo                 |
# |4           |Ainda não recebeu o resultado|
# |9           |Ignorado                     |
# +------------+-----------------------------+
#
#
# 🔹 Construindo DIM para B0103
# +------------+---------------+
# |B0103_codigo|B0103_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C0051
# +------------+---------------+
# |C0051_codigo|C0051_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C0053
# +------------+---------------+
# |C0053_codigo|C0053_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0033
# +------------+---------------+
# |D0033_codigo|D0033_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0013
# +------------+---------------+
# |B0013_codigo|B0013_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0014
# +------------+---------------+
# |B0014_codigo|B0014_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B002
# +-----------+--------------+
# |B002_codigo|B002_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# |9          |Ignorado      |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B005
# +-----------+----------------+
# |B005_codigo|B005_descricao  |
# +-----------+----------------+
# |1          |Sim             |
# |2          |Não             |
# |3          |Não foi atendido|
# |9          |Ignorado        |
# +-----------+----------------+
#
#
# 🔹 Construindo DIM para C007F
# +------------+---------------+
# |C007F_codigo|C007F_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C01011
# +-------------+----------------+
# |C01011_codigo|C01011_descricao|
# +-------------+----------------+
# |0            |0 - 100         |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C011A2
# +-------------+--------------------------+
# |C011A2_codigo|C011A2_descricao          |
# +-------------+--------------------------+
# |2            |Em produtos ou mercadorias|
# +-------------+--------------------------+
#
#
# 🔹 Construindo DIM para D0061
# +------------+---------------+
# |D0061_codigo|D0061_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para E0024
# +------------+---------------+
# |E0024_codigo|E0024_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para V1016
# +------------+---------------+
# |V1016_codigo|V1016_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A004
# +-----------+--------------+
# |A004_codigo|A004_descricao|
# +-----------+--------------+
# |1          |Branca        |
# |2          |Preta         |
# |3          |Amarela       |
# |4          |Parda         |
# |5          |Indígena      |
# |9          |Ignorado      |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B0011
# +------------+---------------+
# |B0011_codigo|B0011_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0037
# +------------+---------------+
# |B0037_codigo|B0037_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0044
# +------------+---------------+
# |B0044_codigo|B0044_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C002
# +-----------+--------------+
# |C002_codigo|C002_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C011A12
# +--------------+-----------------+
# |C011A12_codigo|C011A12_descricao|
# +--------------+-----------------+
# +--------------+-----------------+
#
#
# 🔹 Construindo DIM para C016
# +-----------+--------------------------------------------------------------------+
# |C016_codigo|C016_descricao                                                      |
# +-----------+--------------------------------------------------------------------+
# |1          |Devido à pandemia (isolamento, quarentena ou distanciamento social) |
# |2          |Por problemas de saúde ou gravidez                                  |
# |3          |Estava estudando                                                    |
# |4          |Não quer trabalhar ou é aposentado                                  |
# |5          |Não tinha experiência profissional ou qualificação                  |
# |6          |Acha que não vai encontrar trabalho por ser muito jovem ou idoso    |
# |7          |Não havia trabalho na localidade                                    |
# |8          |Tinha que cuidar dos afazeres domésticos e ou de parentes           |
# |9          |Estava aguardando resposta de medida tomada para conseguir trabalho |
# |10         |Outro motivo                                                        |
# +-----------+--------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para D0021
# +------------+---------------+
# |D0021_codigo|D0021_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0023
# +------------+---------------+
# |D0023_codigo|D0023_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para F0021
# +------------+---------------+
# |F0021_codigo|F0021_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para V1013
# +------------+---------------+
# |V1013_codigo|V1013_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A001
# +-----------+--------------+
# |A001_codigo|A001_descricao|
# +-----------+--------------+
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para A007
# +-----------+-------------------------------------------+
# |A007_codigo|A007_descricao                             |
# +-----------+-------------------------------------------+
# |1          |Sim, e realizou pelo menos parte delas     |
# |2          |Sim, mas não realizou (por qualquer motivo)|
# |3          |Não                                        |
# |4          |Não, porque estava de férias               |
# +-----------+-------------------------------------------+
#
#
# 🔹 Construindo DIM para B0018
# +------------+---------------+
# |B0018_codigo|B0018_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0035
# +------------+---------------+
# |B0035_codigo|B0035_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0042
# +------------+---------------+
# |B0042_codigo|B0042_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B007
# +-----------+--------------+
# |B007_codigo|B007_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# |9          |Ignorado      |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C006
# +-----------+--------------+
# |C006_codigo|C006_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para F002A1
# +-------------+----------------+
# |F002A1_codigo|F002A1_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para V1031
# +------------+---------------+
# |V1031_codigo|V1031_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0032
# +------------+---------------+
# |B0032_codigo|B0032_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0043
# +------------+---------------+
# |B0043_codigo|B0043_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0046
# +------------+---------------+
# |B0046_codigo|B0046_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B0102
# +------------+---------------+
# |B0102_codigo|B0102_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C011A
# +------------+----------------------------------+
# |C011A_codigo|C011A_descricao                   |
# +------------+----------------------------------+
# |1           |Indica se o quesito foi respondido|
# +------------+----------------------------------+
#
#
# 🔹 Construindo DIM para C017A
# +------------+---------------+
# |C017A_codigo|C017A_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0073
# +------------+---------------+
# |D0073_codigo|D0073_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para F002A2
# +-------------+----------------+
# |F002A2_codigo|F002A2_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para A001A
# +------------+------------------------------------------------------+
# |A001A_codigo|A001A_descricao                                       |
# +------------+------------------------------------------------------+
# |1           |Pessoa responsável pelo domicílio                     |
# |2           |Cônjuge ou companheiro(a) de sexo diferente           |
# |3           |Cônjuge ou companheiro(a) do mesmo sexo               |
# |4           |Filho(a) do responsável e do cônjuge                  |
# |5           |Filho(a) somente do responsável                       |
# |6           |Filho(a) somente do cônjuge                           |
# |7           |Genro ou nora                                         |
# |8           |Pai, mãe, padrasto ou madrasta                        |
# |9           |Sogro(a)                                              |
# |10          |Neto(a)                                               |
# |11          |Bisneto(a)                                            |
# |12          |Irmão ou irmã                                         |
# |13          |Avô ou avó                                            |
# |14          |Outro parente                                         |
# |15          |Agregado(a) - Não parente que não compartilha despesas|
# |16          |Convivente - Não parente que compartilha despesas     |
# |17          |Pensionista                                           |
# |18          |Empregado(a) doméstico(a)                             |
# |19          |Parente do(a) empregado(a) doméstico(a)               |
# +------------+------------------------------------------------------+
#
#
# 🔹 Construindo DIM para B006
# +-----------+--------------+
# |B006_codigo|B006_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# |9          |Ignorado      |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B0105
# +------------+---------------+
# |B0105_codigo|B0105_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para B011
# +-----------+--------------------------------------------------------------------------------------------------------------------------------+
# |B011_codigo|B011_descricao                                                                                                                  |
# +-----------+--------------------------------------------------------------------------------------------------------------------------------+
# |1          |Não fez restrição, levou vida normal como antes da pandemia                                                                     |
# |2          |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|
# |3          |Ficou em casa e só saiu em caso de necessidade básica                                                                           |
# |4          |Ficou rigorosamente em casa                                                                                                     |
# |9          |Ignorado                                                                                                                        |
# +-----------+--------------------------------------------------------------------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para C007
# +-----------+---------------------------------------------------------------------------------------------------------------------------+
# |C007_codigo|C007_descricao                                                                                                             |
# +-----------+---------------------------------------------------------------------------------------------------------------------------+
# |1          |Trabalhador doméstico (empregado doméstico, cuidados, babá)                                                                |
# |2          |Militar do exercito, marinha ou aeronáutica                                                                                |
# |3          |Policial militar ou bombeiro militar                                                                                       |
# |4          |Empregado do setor privado                                                                                                 |
# |5          |Empregado do setor público (inclusive empresas de economia mista)                                                          |
# |6          |Empregador                                                                                                                 |
# |7          |Conta própria                                                                                                              |
# |8          |Trabalhador familiar não remunerado em ajuda a membro do domicílio ou parente                                              |
# |9          |Estava fora do mercado de trabalho (fazia apenas afazeres domésticos, cuidados de pessoas ou produção para próprio consumo)|
# +-----------+---------------------------------------------------------------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para D0011
# +------------+---------------+
# |D0011_codigo|D0011_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para F002A5
# +-------------+----------------+
# |F002A5_codigo|F002A5_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para A001B2
# +-------------+----------------+
# |A001B2_codigo|A001B2_descricao|
# +-------------+----------------+
# |99           |Não informado   |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para A008
# +-----------+--------------+
# |A008_codigo|A008_descricao|
# +-----------+--------------+
# |1          |1 dia         |
# |2          |2 dias        |
# |3          |3 dias        |
# |4          |4 dias        |
# |5          |5 dias        |
# |6          |6 ou 7 dias   |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para B00112
# +-------------+----------------+
# |B00112_codigo|B00112_descricao|
# +-------------+----------------+
# |1            |Sim             |
# |2            |Não             |
# |3            |Não sabe        |
# |9            |Ignorado        |
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para C0103
# +------------+---------------+
# |C0103_codigo|C0103_descricao|
# +------------+---------------+
# |3           |Em benefícios  |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C011A11
# +--------------+-----------------+
# |C011A11_codigo|C011A11_descricao|
# +--------------+-----------------+
# |0             |0 - 100          |
# +--------------+-----------------+
#
#
# 🔹 Construindo DIM para D0051
# +------------+---------------+
# |D0051_codigo|D0051_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0071
# +------------+---------------+
# |D0071_codigo|D0071_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para E0022
# +------------+---------------+
# |E0022_codigo|E0022_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para V1023
# +------------+-----------------------------------------------------------------------------------+
# |V1023_codigo|V1023_descricao                                                                    |
# +------------+-----------------------------------------------------------------------------------+
# |1           |Capital                                                                            |
# |2           |Resto da RM (Região Metropolitana, excluindo a capital)                            |
# |3           |Resto da RIDE (Região Integrada de Desenvolvimento Econômico, excluindo a capital) |
# |4           |Resto da UF  (Unidade da Federação, excluindo a região metropolitana e a RIDE)     |
# +------------+-----------------------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para B008
# +-----------+--------------+
# |B008_codigo|B008_descricao|
# +-----------+--------------+
# |1          |Sim           |
# |2          |Não           |
# |9          |Ignorado      |
# +-----------+--------------+
#
#
# 🔹 Construindo DIM para C009A
# +------------+---------------+
# |C009A_codigo|C009A_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C0101
# +------------+---------------+
# |C0101_codigo|C0101_descricao|
# +------------+---------------+
# |1           |Em dinheiro    |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C0102
# +------------+--------------------------+
# |C0102_codigo|C0102_descricao           |
# +------------+--------------------------+
# |2           |Em produtos ou mercadorias|
# +------------+--------------------------+
#
#
# 🔹 Construindo DIM para D0053
# +------------+---------------+
# |D0053_codigo|D0053_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A001B3
# +-------------+----------------+
# |A001B3_codigo|A001B3_descricao|
# +-------------+----------------+
# +-------------+----------------+
#
#
# 🔹 Construindo DIM para B0016
# +------------+---------------+
# |B0016_codigo|B0016_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# |3           |Não sabe       |
# |9           |Ignorado       |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para C007B
# +------------+--------------------------------------+
# |C007B_codigo|C007B_descricao                       |
# +------------+--------------------------------------+
# |1           |Sim, tem carteira de trabalho assinada|
# |2           |Sim, é servidor público estatutário   |
# |3           |Não                                   |
# +------------+--------------------------------------+
#
#
# 🔹 Construindo DIM para C010
# +-----------+----------------------------------+
# |C010_codigo|C010_descricao                    |
# +-----------+----------------------------------+
# |1          |Indica se o quesito foi respondido|
# +-----------+----------------------------------+
#
#
# 🔹 Construindo DIM para D0013
# +------------+---------------+
# |D0013_codigo|D0013_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para D0063
# +------------+---------------+
# |D0063_codigo|D0063_descricao|
# +------------+---------------+
# +------------+---------------+
#
#
# 🔹 Construindo DIM para E0021
# +------------+---------------+
# |E0021_codigo|E0021_descricao|
# +------------+---------------+
# |1           |Sim            |
# |2           |Não            |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A007A
# +------------+------------------------------------------------------------------------------+
# |A007A_codigo|A007A_descricao                                                               |
# +------------+------------------------------------------------------------------------------+
# |1           |Não tinha computador / tablet / celular disponível                            |
# |2           |Não tinha acesso à internet ou a qualidade dela era insuficiente              |
# |3           |Por problemas de saúde da própria pessoa                                      |
# |4           |Tinha que cuidar dos afazeres domésticos, do(s) filhos ou de outro(s) parentes|
# |5           |Não conseguiu se concentrar                                                   |
# |6           |Outro motivo. Especifique.                                                    |
# +------------+------------------------------------------------------------------------------+
#
#
# 🔹 Construindo DIM para A006A
# +------------+---------------+
# |A006A_codigo|A006A_descricao|
# +------------+---------------+
# |1           |Pública        |
# |2           |Privada        |
# +------------+---------------+
#
#
# 🔹 Construindo DIM para A006B
# +------------+--------------------------------------------------+
# |A006B_codigo|A006B_descricao                                   |
# +------------+--------------------------------------------------+
# |1           |Sim, normalmente                                  |
# |2           |Sim, mas apenas parcialmente                      |
# |3           |Não, e meu normalmente é presencial/semipresencial|
# |4           |Não, meu curso é online                           |
# +------------+--------------------------------------------------+

# %%
micro_unificado.write \
    .format("parquet") \
    .mode("overwrite") \
    .option("path", "s3://lab-746762238259/data-output/pnad_covid_bronze/") \
    .option("compression", "snappy") \
    .saveAsTable("workspace.tb_pnad_covid_bronze")

df_dict.write \
    .format("parquet") \
    .mode("overwrite") \
    .option("path", "s3://lab-746762238259/data-output/pnad_covid_bronze/") \
    .option("compression", "snappy") \
    .saveAsTable("workspace.tb_pnad_covid_bronze")

# %% [markdown]
# # CAMADA SILVER
# ### Tradução dos Valores dos Microdados
#
# Descrição:
# Aplica a tradução dos códigos para descrições textuais no DataFrame unificado de microdados. Para cada variável que possui uma dimensão correspondente, substitui os códigos numéricos por suas descrições textuais usando mapeamento.

# %%
from pyspark.sql import functions as F
from itertools import chain

# micro_traduzido começa como cópia do micro original
micro_traduzido = micro_unificado

for var, dim in dims.items():
    print(f"🔁 Traduzindo valores da coluna {var}...")

    # Coletar mapeamento codigo -> descricao
    mapping = (
        dim
        .select(
            F.col(f"{var}_codigo").cast("string"),
            F.col(f"{var}_descricao")
        )
        .dropna()
        .distinct()
        .collect()
    )

    if not mapping:
        print(f"⚠️ Nenhum mapeamento encontrado para {var}, pulando.")
        continue

    # Criar map literal (Spark)
    map_expr = F.create_map(
        *list(chain.from_iterable(
            [(F.lit(r[0]), F.lit(r[1])) for r in mapping]
        ))
    )

    # Aplicar tradução IN-PLACE
    micro_traduzido = micro_traduzido.withColumn(
        var,
        F.coalesce(
            map_expr[F.col(var).cast("string")],
            F.col(var).cast("string")
        )
    )

# ===========================
# Validação
# ===========================
print("\n=== Preview após tradução IN-PLACE ===")
micro_traduzido.show(10, truncate=False)
# Out:
# 🔁 Traduzindo valores da coluna A001B1...
# 🔁 Traduzindo valores da coluna B0015...
# 🔁 Traduzindo valores da coluna B0019...
# 🔁 Traduzindo valores da coluna B00111...
# 🔁 Traduzindo valores da coluna B0034...
# 🔁 Traduzindo valores da coluna B0045...
# 🔁 Traduzindo valores da coluna C005...
# 🔁 Traduzindo valores da coluna C009...
# ⚠️ Nenhum mapeamento encontrado para C009, pulando.
# 🔁 Traduzindo valores da coluna A009...
# 🔁 Traduzindo valores da coluna C004...
# 🔁 Traduzindo valores da coluna C01022...
# ⚠️ Nenhum mapeamento encontrado para C01022, pulando.
# 🔁 Traduzindo valores da coluna C012...
# 🔁 Traduzindo valores da coluna C013...
# 🔁 Traduzindo valores da coluna D0043...
# ⚠️ Nenhum mapeamento encontrado para D0043, pulando.
# 🔁 Traduzindo valores da coluna F002A4...
# 🔁 Traduzindo valores da coluna B0031...
# 🔁 Traduzindo valores da coluna B0033...
# 🔁 Traduzindo valores da coluna B0041...
# 🔁 Traduzindo valores da coluna B009A...
# 🔁 Traduzindo valores da coluna B009E...
# 🔁 Traduzindo valores da coluna B0101...
# 🔁 Traduzindo valores da coluna B0106...
# 🔁 Traduzindo valores da coluna C003...
# 🔁 Traduzindo valores da coluna C0052...
# ⚠️ Nenhum mapeamento encontrado para C0052, pulando.
# 🔁 Traduzindo valores da coluna C007E1...
# ⚠️ Nenhum mapeamento encontrado para C007E1, pulando.
# 🔁 Traduzindo valores da coluna C008...
# ⚠️ Nenhum mapeamento encontrado para C008, pulando.
# 🔁 Traduzindo valores da coluna C0104...
# 🔁 Traduzindo valores da coluna C011A22...
# ⚠️ Nenhum mapeamento encontrado para C011A22, pulando.
# 🔁 Traduzindo valores da coluna F0022...
# 🔁 Traduzindo valores da coluna UPA...
# ⚠️ Nenhum mapeamento encontrado para UPA, pulando.
# 🔁 Traduzindo valores da coluna V1022...
# 🔁 Traduzindo valores da coluna B0017...
# 🔁 Traduzindo valores da coluna B0036...
# 🔁 Traduzindo valores da coluna B0104...
# 🔁 Traduzindo valores da coluna C007D...
# 🔁 Traduzindo valores da coluna C01021...
# 🔁 Traduzindo valores da coluna C011A21...
# 🔁 Traduzindo valores da coluna E0023...
# 🔁 Traduzindo valores da coluna F001...
# 🔁 Traduzindo valores da coluna F0061...
# 🔁 Traduzindo valores da coluna V1012...
# ⚠️ Nenhum mapeamento encontrado para V1012, pulando.
# 🔁 Traduzindo valores da coluna Estrato...
# ⚠️ Nenhum mapeamento encontrado para Estrato, pulando.
# 🔁 Traduzindo valores da coluna A005...
# 🔁 Traduzindo valores da coluna B0012...
# 🔁 Traduzindo valores da coluna B00113...
# 🔁 Traduzindo valores da coluna B009C...
# 🔁 Traduzindo valores da coluna C001...
# 🔁 Traduzindo valores da coluna C014...
# 🔁 Traduzindo valores da coluna E001...
# 🔁 Traduzindo valores da coluna F006...
# ⚠️ Nenhum mapeamento encontrado para F006, pulando.
# 🔁 Traduzindo valores da coluna UF...
# 🔁 Traduzindo valores da coluna V1008...
# ⚠️ Nenhum mapeamento encontrado para V1008, pulando.
# 🔁 Traduzindo valores da coluna C007C...
# 🔁 Traduzindo valores da coluna C007E...
# 🔁 Traduzindo valores da coluna C007E2...
# ⚠️ Nenhum mapeamento encontrado para C007E2, pulando.
# 🔁 Traduzindo valores da coluna C01012...
# ⚠️ Nenhum mapeamento encontrado para C01012, pulando.
# 🔁 Traduzindo valores da coluna C011A1...
# 🔁 Traduzindo valores da coluna C015...
# 🔁 Traduzindo valores da coluna F002A3...
# 🔁 Traduzindo valores da coluna CAPITAL...
# 🔁 Traduzindo valores da coluna V1032...
# ⚠️ Nenhum mapeamento encontrado para V1032, pulando.
# 🔁 Traduzindo valores da coluna A003...
# 🔁 Traduzindo valores da coluna B009D...
# 🔁 Traduzindo valores da coluna B009F...
# 🔁 Traduzindo valores da coluna C007A...
# 🔁 Traduzindo valores da coluna D0031...
# 🔁 Traduzindo valores da coluna D0041...
# 🔁 Traduzindo valores da coluna A002...
# ⚠️ Nenhum mapeamento encontrado para A002, pulando.
# 🔁 Traduzindo valores da coluna A006...
# 🔁 Traduzindo valores da coluna B00110...
# 🔁 Traduzindo valores da coluna B009B...
# 🔁 Traduzindo valores da coluna B0103...
# 🔁 Traduzindo valores da coluna C0051...
# ⚠️ Nenhum mapeamento encontrado para C0051, pulando.
# 🔁 Traduzindo valores da coluna C0053...
# ⚠️ Nenhum mapeamento encontrado para C0053, pulando.
# 🔁 Traduzindo valores da coluna D0033...
# ⚠️ Nenhum mapeamento encontrado para D0033, pulando.
# 🔁 Traduzindo valores da coluna B0013...
# 🔁 Traduzindo valores da coluna B0014...
# 🔁 Traduzindo valores da coluna B002...
# 🔁 Traduzindo valores da coluna B005...
# 🔁 Traduzindo valores da coluna C007F...
# 🔁 Traduzindo valores da coluna C01011...
# 🔁 Traduzindo valores da coluna C011A2...
# 🔁 Traduzindo valores da coluna D0061...
# 🔁 Traduzindo valores da coluna E0024...
# 🔁 Traduzindo valores da coluna V1016...
# ⚠️ Nenhum mapeamento encontrado para V1016, pulando.
# 🔁 Traduzindo valores da coluna A004...
# 🔁 Traduzindo valores da coluna B0011...
# 🔁 Traduzindo valores da coluna B0037...
# 🔁 Traduzindo valores da coluna B0044...
# 🔁 Traduzindo valores da coluna C002...
# 🔁 Traduzindo valores da coluna C011A12...
# ⚠️ Nenhum mapeamento encontrado para C011A12, pulando.
# 🔁 Traduzindo valores da coluna C016...
# 🔁 Traduzindo valores da coluna D0021...
# 🔁 Traduzindo valores da coluna D0023...
# ⚠️ Nenhum mapeamento encontrado para D0023, pulando.
# 🔁 Traduzindo valores da coluna F0021...
# ⚠️ Nenhum mapeamento encontrado para F0021, pulando.
# 🔁 Traduzindo valores da coluna V1013...
# ⚠️ Nenhum mapeamento encontrado para V1013, pulando.
# 🔁 Traduzindo valores da coluna A001...
# ⚠️ Nenhum mapeamento encontrado para A001, pulando.
# 🔁 Traduzindo valores da coluna A007...
# 🔁 Traduzindo valores da coluna B0018...
# 🔁 Traduzindo valores da coluna B0035...
# 🔁 Traduzindo valores da coluna B0042...
# 🔁 Traduzindo valores da coluna B007...
# 🔁 Traduzindo valores da coluna C006...
# 🔁 Traduzindo valores da coluna F002A1...
# 🔁 Traduzindo valores da coluna V1031...
# ⚠️ Nenhum mapeamento encontrado para V1031, pulando.
# 🔁 Traduzindo valores da coluna B0032...
# 🔁 Traduzindo valores da coluna B0043...
# 🔁 Traduzindo valores da coluna B0046...
# 🔁 Traduzindo valores da coluna B0102...
# 🔁 Traduzindo valores da coluna C011A...
# 🔁 Traduzindo valores da coluna C017A...
# 🔁 Traduzindo valores da coluna D0073...
# ⚠️ Nenhum mapeamento encontrado para D0073, pulando.
# 🔁 Traduzindo valores da coluna F002A2...
# 🔁 Traduzindo valores da coluna A001A...
# 🔁 Traduzindo valores da coluna B006...
# 🔁 Traduzindo valores da coluna B0105...
# 🔁 Traduzindo valores da coluna B011...
# 🔁 Traduzindo valores da coluna C007...
# 🔁 Traduzindo valores da coluna D0011...
# 🔁 Traduzindo valores da coluna F002A5...
# 🔁 Traduzindo valores da coluna A001B2...
# 🔁 Traduzindo valores da coluna A008...
# 🔁 Traduzindo valores da coluna B00112...
# 🔁 Traduzindo valores da coluna C0103...
# 🔁 Traduzindo valores da coluna C011A11...
# 🔁 Traduzindo valores da coluna D0051...
# 🔁 Traduzindo valores da coluna D0071...
# 🔁 Traduzindo valores da coluna E0022...
# 🔁 Traduzindo valores da coluna V1023...
# 🔁 Traduzindo valores da coluna B008...
# 🔁 Traduzindo valores da coluna C009A...
# 🔁 Traduzindo valores da coluna C0101...
# 🔁 Traduzindo valores da coluna C0102...
# 🔁 Traduzindo valores da coluna D0053...
# ⚠️ Nenhum mapeamento encontrado para D0053, pulando.
# 🔁 Traduzindo valores da coluna A001B3...
# ⚠️ Nenhum mapeamento encontrado para A001B3, pulando.
# 🔁 Traduzindo valores da coluna B0016...
# 🔁 Traduzindo valores da coluna C007B...
# 🔁 Traduzindo valores da coluna C010...
# 🔁 Traduzindo valores da coluna D0013...
# ⚠️ Nenhum mapeamento encontrado para D0013, pulando.
# 🔁 Traduzindo valores da coluna D0063...
# ⚠️ Nenhum mapeamento encontrado para D0063, pulando.
# 🔁 Traduzindo valores da coluna E0021...
# 🔁 Traduzindo valores da coluna A007A...
# 🔁 Traduzindo valores da coluna A006A...
# 🔁 Traduzindo valores da coluna A006B...
#
# === Preview após tradução IN-PLACE ===
# +----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+---------------------------------------------------------------+---------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# |Ano |UF      |CAPITAL                      |RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022 |V1023  |V1030 |V1031       |V1032       |posest|A001|A001A                                      |A001B1       |A001B2       |A001B3|A002|A003  |A004  |A005                  |A006|A007                                  |A008  |A009                         |B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011                                                                                                                            |C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007                       |C007A|C007B                                 |C007C                                                          |C007D                            |C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010                              |C0101      |C01011 |C01012|C0102|C01021|C01022|C0103|C0104|C011A                             |C011A1     |C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016                                                               |C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001         |E0021|E0022|E0023|E0024|F001              |F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061          |F006|A006A|A006B|A007A|
# +----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+---------------------------------------------------------------+---------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|152677|133.93337786|164.20936068|1114  |1   |Pessoa responsável pelo domicílio          |5            |8            |1984  |36  |Homem |Parda |Médio completo        |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Empregado do setor privado |null |Sim, tem carteira de trabalho assinada|Outro técnico ou profissional de nível médio                   |Comércio no atacado e varejo;    |null |null  |null  |null |48  |48  |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045   |null  |null   |null   |Sim |null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|150642|133.93337786|166.94461021|1124  |2   |Cônjuge ou companheiro(a) de sexo diferente|18           |8            |1990  |30  |Mulher|Parda |Superior completo     |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Técnico, profissional da saúde de nível médio                  |Saúde humana e assistência social|null |null  |null  |null |36  |36  |Não  |Indica se o quesito foi respondido|Em dinheiro|4      |1045  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045   |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |3   |Filho(a) do responsável e do cônjuge       |25           |12           |2006  |13  |Homem |Parda |Fundamental incompleto|Sim |Sim, e realizou pelo menos parte delas|5 dias|De 2 horas a menos de 5 horas|Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |4   |Filho(a) do responsável e do cônjuge       |24           |8            |2009  |11  |Homem |Parda |Fundamental incompleto|Sim |Sim, e realizou pelo menos parte delas|5 dias|De 2 horas a menos de 5 horas|Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |2    |1    |9    |5    |1110011|110015970|Urbana|Capital|91889 |133.93337786|127.53668218|1126  |1   |Pessoa responsável pelo domicílio          |18           |5            |1963  |57  |Mulher|Branca|Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Devido à pandemia (isolamento, quarentena ou distanciamento social)|Sim  |Não  |null |Não  |null |Não  |null |Sim  |1045 |Não  |null |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |3    |2    |9    |5    |1110011|110015970|Urbana|Capital|91889 |133.93337786|127.53668218|1126  |1   |Pessoa responsável pelo domicílio          |25           |12           |1961  |58  |Mulher|Preta |Sem instrução         |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Sim  |Sim  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Outros                                                         |Outro                            |null |null  |null  |null |40  |40  |null |Indica se o quesito foi respondido|Em dinheiro|0 - 100|100   |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|0 - 100|60     |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Sim  |1045 |Não  |null |Não  |null |Não  |null |Não  |null |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|123242|133.93337786|164.39829286|1115  |1   |Pessoa responsável pelo domicílio          |18           |2            |1973  |47  |Homem |Parda |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Pedreiro, servente de pedreiro, pintor, eletricista, marceneiro|Construção                       |null |null  |null  |null |40  |20  |Sim  |Indica se o quesito foi respondido|Em dinheiro|4      |1500  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|2      |600    |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|139056|133.93337786|163.71468056|1122  |4   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |18  |Mulher|Parda |Fundamental incompleto|Não |null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Estava estudando                                                   |Não  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |7   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |11  |Homem |Parda |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|134071|133.93337786|170.11202829|1121  |9   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |9   |Mulher|Parda |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                           |null                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# +----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+---------------------------------------------------------------+---------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# only showing top 10 rows

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# Criar DataFrame com ID como primeira coluna
micro_traduzido = micro_traduzido.select(
    F.row_number().over(Window.orderBy(F.monotonically_increasing_id())).alias("ID"),
    *micro_traduzido.columns  # todas as outras colunas
)

# %% [markdown]
# ### Visualização dos Dados Traduzidos
#
# Descrição:
# Exibe as primeiras linhas do DataFrame de microdados após a tradução, mostrando os valores já convertidos em formato legível.

# %%
micro_traduzido.show(20, truncate=False)
# Out:
# +---+----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+-------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+------------------------------------------------------------------+-------------------------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+--------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# |ID |Ano |UF      |CAPITAL                      |RM_RIDE|V1008|V1012|V1013|V1016|Estrato|UPA      |V1022 |V1023  |V1030 |V1031       |V1032       |posest|A001|A001A                                      |A001B1       |A001B2       |A001B3|A002|A003  |A004   |A005                  |A006|A007                                  |A008  |A009                         |B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|B011                                                                                                                            |C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|C007                       |C007A|C007B                                 |C007C                                                             |C007D                                            |C007E|C007E1|C007E2|C007F|C008|C009|C009A|C010                              |C0101      |C01011 |C01012|C0102|C01021|C01022|C0103|C0104|C011A                             |C011A1     |C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016                                                               |C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|E001         |E0021|E0022|E0023|E0024|F001                |F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|F0061          |F006|A006A|A006B|A007A|
# +---+----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+-------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+------------------------------------------------------------------+-------------------------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+--------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# |1  |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|152677|133.93337786|164.20936068|1114  |1   |Pessoa responsável pelo domicílio          |5            |8            |1984  |36  |Homem |Parda  |Médio completo        |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Empregado do setor privado |null |Sim, tem carteira de trabalho assinada|Outro técnico ou profissional de nível médio                      |Comércio no atacado e varejo;                    |null |null  |null  |null |48  |48  |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045   |null  |null   |null   |Sim |null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |2  |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|150642|133.93337786|166.94461021|1124  |2   |Cônjuge ou companheiro(a) de sexo diferente|18           |8            |1990  |30  |Mulher|Parda  |Superior completo     |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Técnico, profissional da saúde de nível médio                     |Saúde humana e assistência social                |null |null  |null  |null |36  |36  |Não  |Indica se o quesito foi respondido|Em dinheiro|4      |1045  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045   |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |3  |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |3   |Filho(a) do responsável e do cônjuge       |25           |12           |2006  |13  |Homem |Parda  |Fundamental incompleto|Sim |Sim, e realizou pelo menos parte delas|5 dias|De 2 horas a menos de 5 horas|Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |4  |2020|Rondônia|Município de Porto Velho (RO)|null   |1    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |4   |Filho(a) do responsável e do cônjuge       |24           |8            |2009  |11  |Homem |Parda  |Fundamental incompleto|Sim |Sim, e realizou pelo menos parte delas|5 dias|De 2 horas a menos de 5 horas|Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Sim |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |5  |2020|Rondônia|Município de Porto Velho (RO)|null   |2    |1    |9    |5    |1110011|110015970|Urbana|Capital|91889 |133.93337786|127.53668218|1126  |1   |Pessoa responsável pelo domicílio          |18           |5            |1963  |57  |Mulher|Branca |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Devido à pandemia (isolamento, quarentena ou distanciamento social)|Sim  |Não  |null |Não  |null |Não  |null |Sim  |1045 |Não  |null |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |6  |2020|Rondônia|Município de Porto Velho (RO)|null   |3    |2    |9    |5    |1110011|110015970|Urbana|Capital|91889 |133.93337786|127.53668218|1126  |1   |Pessoa responsável pelo domicílio          |25           |12           |1961  |58  |Mulher|Preta  |Sem instrução         |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Sim  |Sim  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Outros                                                            |Outro                                            |null |null  |null  |null |40  |40  |null |Indica se o quesito foi respondido|Em dinheiro|0 - 100|100   |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|0 - 100|60     |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Sim  |1045 |Não  |null |Não  |null |Não  |null |Não  |null |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |7  |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|123242|133.93337786|164.39829286|1115  |1   |Pessoa responsável pelo domicílio          |18           |2            |1973  |47  |Homem |Parda  |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Pedreiro, servente de pedreiro, pintor, eletricista, marceneiro   |Construção                                       |null |null  |null  |null |40  |20  |Sim  |Indica se o quesito foi respondido|Em dinheiro|4      |1500  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|2      |600    |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |8  |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|139056|133.93337786|163.71468056|1122  |4   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |18  |Mulher|Parda  |Fundamental incompleto|Não |null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Estava estudando                                                   |Não  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |9  |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |7   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |11  |Homem |Parda  |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |10 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|134071|133.93337786|170.11202829|1121  |9   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |9   |Mulher|Parda  |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |11 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |8   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |10  |Homem |Parda  |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |null|null|null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|null|null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |12 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|157535|133.93337786|173.37803588|1113  |3   |Filho(a) somente do responsável            |3            |3            |1994  |26  |Homem |Parda  |Médio completo        |Não |null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Agricultor, criador de animais, pescador, silvicultor e jardineiro|Agricultura, pecuária, produção florestal e pesca|null |null  |null  |null |40  |40  |null |Indica se o quesito foi respondido|Em dinheiro|4      |1500  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|2      |600    |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |13 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|145237|133.93337786|171.88775372|1112  |6   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |14  |Homem |Amarela|Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Sim |null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |14 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|139056|133.93337786|163.71468056|1122  |5   |Filho(a) somente do responsável            |Não informado|Não informado|9999  |15  |Mulher|Parda  |Fundamental incompleto|Sim |Não, porque estava de férias          |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou rigorosamente em casa                                                                                                     |Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Não quer trabalhar ou é aposentado                                 |Não  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |15 |2020|Rondônia|Município de Porto Velho (RO)|null   |4    |4    |9    |5    |1110011|110015970|Urbana|Capital|150642|133.93337786|166.94461021|1124  |2   |Cônjuge ou companheiro(a) de sexo diferente|Não informado|Não informado|9999  |33  |Mulher|Parda  |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Devido à pandemia (isolamento, quarentena ou distanciamento social)|Sim  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |16 |2020|Rondônia|Município de Porto Velho (RO)|null   |5    |3    |9    |5    |1110011|110015970|Urbana|Capital|56521 |133.93337786|131.11800423|1117  |1   |Pessoa responsável pelo domicílio          |25           |5            |1958  |62  |Homem |Parda  |Sem instrução         |null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Mecânico de veículos, máquinas industriais etc.                   |Reparação de veículos automotores e motocicletas |null |null  |null  |null |44  |44  |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1045   |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Cedido por familiar |null |null |Sim   |Sim   |Sim   |Sim   |Sim   |Pessoa moradora|1   |null |null |null |
# |17 |2020|Rondônia|Município de Porto Velho (RO)|null   |5    |3    |9    |5    |1110011|110015970|Urbana|Capital|55357 |133.93337786|116.49045266|1127  |2   |Cônjuge ou companheiro(a) de sexo diferente|31           |3            |1958  |62  |Mulher|Parda  |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Sim |null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |600  |Não  |null |Não  |null |Não solicitou|null |null |null |null |Cedido por familiar |null |null |Sim   |Sim   |Sim   |Sim   |Sim   |Pessoa moradora|1   |null |null |null |
# |18 |2020|Rondônia|Município de Porto Velho (RO)|null   |6    |2    |9    |5    |1110011|110015970|Urbana|Capital|91889 |133.93337786|127.53668218|1126  |1   |Pessoa responsável pelo domicílio          |1            |11           |1963  |56  |Mulher|Parda  |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Sim  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Tinha que cuidar dos afazeres domésticos e ou de parentes          |Sim  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |19 |2020|Rondônia|Município de Porto Velho (RO)|null   |6    |2    |9    |5    |1110011|110015970|Urbana|Capital|95808 |133.93337786|146.59504674|1116  |2   |Cônjuge ou companheiro(a) de sexo diferente|29           |5            |1967  |53  |Homem |Preta  |Fundamental incompleto|null|null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Ficou em casa e só saiu em caso de necessidade básica                                                                           |Sim |null|null|null|null|null |null |null |Não |Conta própria              |null |null                                  |Pedreiro, servente de pedreiro, pintor, eletricista, marceneiro   |Construção                                       |null |null  |null  |null |40  |40  |null |Indica se o quesito foi respondido|Em dinheiro|4      |1600  |null |null  |null  |null |null |Indica se o quesito foi respondido|Em dinheiro|4      |1000   |null  |null   |null   |Sim |null|Não |null|null                                                               |null |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# |20 |2020|Rondônia|Município de Porto Velho (RO)|null   |6    |2    |9    |5    |1110011|110015970|Urbana|Capital|139056|133.93337786|163.71468056|1122  |3   |Filho(a) do responsável e do cônjuge       |20           |12           |2002  |17  |Mulher|Branca |Médio incompleto      |Não |null                                  |null  |null                         |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não  |Não   |Não   |Não   |Não   |null|null |null |null |null |null |null |null |null |null |null |null |null |null |null|null|Não |Não |null |null |null |null |null |null |Não  |Não  |Não  |Não  |Não  |Não  |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas|Não |Não |null|null|null|null |null |null |null|null                       |null |null                                  |null                                                              |null                                             |null |null  |null  |null |null|null|null |null                              |null       |null   |null  |null |null  |null  |null |null |null                              |null       |null   |null   |null  |null   |null   |null|null|Não |Não |Estava estudando                                                   |Não  |Não  |null |Não  |null |Não  |null |Não  |null |Sim  |1200 |Não  |null |Não  |null |Não solicitou|null |null |null |null |Próprio - já pago   |null |null |Sim   |Sim   |Sim   |Não   |Sim   |Pessoa moradora|1   |null |null |null |
# +---+----+--------+-----------------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-------------------------------------------+-------------+-------------+------+----+------+-------+----------------------+----+--------------------------------------+------+-----------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------------------------------------------------------------------------------------------------------------------+----+----+----+----+----+-----+-----+-----+----+---------------------------+-----+--------------------------------------+------------------------------------------------------------------+-------------------------------------------------+-----+------+------+-----+----+----+-----+----------------------------------+-----------+-------+------+-----+------+------+-----+-----+----------------------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+-------------------------------------------------------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+--------------------+-----+-----+------+------+------+------+------+---------------+----+-----+-----+-----+
# only showing top 20 rows

# %% [markdown]
# ### Visualização das Colunas Traduzidos
#
# Descrição:
# Exibe colunas do DataFrame de microdados após a tradução, mostrando os valores já convertidos em formato legível.

# %%
# =====================================================
# Traduzir nomes das colunas do microdados usando df_dict
# PySpark puro (sem Pandas, sem CSV)
# B (codigo) -> D (descricao normalizada)
# =====================================================

from pyspark.sql import functions as F
import unicodedata
import re

# =====================================================
# 1. Função de normalização (driver-side)
# =====================================================
def normaliza_nome_coluna(texto: str) -> str:
    if texto is None:
        return None

    texto = texto.strip().lower()

    # Remove acentos
    texto = unicodedata.normalize("NFKD", texto)
    texto = texto.encode("ascii", "ignore").decode("utf-8")

    # Mantém apenas [a-z0-9_]
    texto = re.sub(r"[^a-z0-9]+", "_", texto)
    texto = re.sub(r"_+", "_", texto).strip("_")

    return texto


# =====================================================
# 2. Extrair pares (codigo -> descricao) do df_dict
#    OBS: inclui linhas is_var=true e false
# =====================================================
pairs = (
    df_dict
    .select(
        F.col("B").cast("string").alias("codigo"),
        F.col("D").cast("string").alias("descricao")
    )
    .where(
        F.col("codigo").isNotNull() &
        F.col("descricao").isNotNull()
    )
    .dropDuplicates()
    .collect()   # necessário para renomear colunas
)

# =====================================================
# 3. Mapa case-insensitive das colunas do micro
# =====================================================
micro_cols_lower = {c.lower(): c for c in micro_traduzido.columns}

# =====================================================
# 4. Criar rename_map (old_col -> new_col)
# =====================================================
rename_map = {}

for r in pairs:
    codigo = r["codigo"].strip().lower()
    descricao = r["descricao"].strip()

    if codigo in micro_cols_lower:
        old_col = micro_cols_lower[codigo]
        new_col = normaliza_nome_coluna(descricao)

        if new_col and new_col != old_col:
            rename_map[old_col] = new_col

# =====================================================
# 5. Aplicar renomeação
# =====================================================
for old, new in rename_map.items():
    micro_traduzido = micro_traduzido.withColumnRenamed(old, new)

# %%
micro_traduzido.show(20, truncate=False)
# Out:
# +---+-----------------+--------------------+-----------------------------+------------------------------------------------------+------------------------------+-------------+---------------+---------------------------------+-------+---------+---------------------+------------+---------------------+-------------------------------+-------------------------------+--------------------+---------------+-------------------------------------------+-----------------+-----------------+-----------------+----------------+------+-----------+----------------------+----------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+----------------------------------------------------------------+-----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+-------------------------------------------------------+----------------+--------------------------------------------------------+----------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+---------------------------------------------- ...
# |ID |ano_de_referencia|unidade_da_federacao|capital                      |regiao_metropolitana_e_regiao_administrativa_integrada|numero_de_selecao_do_domicilio|semana_no_mes|mes_da_pesquisa|numero_da_entrevista_no_domicilio|estrato|upa      |situacao_do_domicilio|tipo_de_area|projecao_da_populacao|peso_do_domicilio_e_das_pessoas|peso_do_domicilio_e_das_pessoas|dominios_de_projecao|numero_de_ordem|condicao_no_domicilio                      |dia_de_nascimento|mes_de_nascimento|ano_de_nascimento|idade_do_morador|sexo  |cor_ou_raca|escolaridade          |frequenta_escola|na_semana_passada_foram_disponibilizadas_atividades_escolares_para_realizar_em_casa|na_semana_passada_em_quantos_dias_dedicou_se_as_atividades_escolares|na_semana_passada_quanto_tempo_por_dia_gastou_fazendo_as_atividades_escolares_escolares|na_semana_passada_teve_febre|na_semana_passada_teve_tosse|na_semana_passada_teve_dor_de_garganta|na_semana_passada_teve_dificuldade_para_respirar|na_semana_passada_teve_dor_de_cabeca|na_semana_passada_teve_dor_no_peito|na_semana_passada_teve_nausea|na_semana_passada_teve_nariz_entupido_ou_escorrendo|na_semana_passada_teve_fadiga|na_semana_passada_teve_dor_nos_olhos|na_semana_passada_teve_perda_de_cheiro_ou_sabor|na_semana_passada_teve_dor_muscular|na_semana_passada_teve_diarreia|por_causa_disso_foi_a_algum_estabelecimento_de_saude|providencia_tomada_para_recuperar_dos_sintomas_foi_ficar_em_casa|providencia_tomada_para_recuperar_dos_sintomas_foi_ligar_para_algum_profissional_de_saude|providencia_tomada_para_recuperar_dos_sintomas_foi_comprar_e_ou_tomar_remedio_por_conta_propria|providencia_tomada_para_recuperar_dos_sintomas_foi_comprar_e_ou_tomar_remedio_por_orientacao_medica|providencia_tomada_para_recuperar_dos_sintomas_foi_receber_visita_de_algum_profissional_de_saude_do_sus_equipe_de_saude_da_familia_agente_comunitario_etc|providencia_tomada_para_recuperar_dos_sintomas_foi_receber_visita_de_profissional_de_saude_particular|providencia_tomada_para_recuperar_dos_sintomas_foi_outra|local_que_buscou_atendimento_foi_posto_de_saude_unidade_basica_de_saude_equipe_de_saude_da_familia_medico_enfermeiro_tecnico_de_enfermagem_ou_agente_comunitario_de_saude|local_que_buscou_atendimento_foi_pronto_socorro_do_sus_upa|local_que_buscou_atendimento_foi_hospital_do_sus|local_que_buscou_atendimento_foi_ambulatorio_ou_consultorio_privado_ou_ligado_as_forcas_armadas|local_que_buscou_atendimento_foi_pronto_socorro_privado_ou_ligado_as_forcas_armadas|local_que_buscou_atendimento_foi_hospital_privado_ou_ligado_as_forcas_armadas|ao_procurar_o_hospital_teve_que_ficar_internado_por_um_dia_ou_mais|durante_a_internacao_foi_sedado_entubado_e_colocado_em_respiracao_artificial_com_ventilador|tem_algum_plano_de_saude_medico_seja_particular_de_empresa_ou_de_orgao_publico|o_a_sr_a_fez_algum_teste_para_saber_se_estava_infectado_a_pelo_coronavirus|fez_o_exame_coletado_com_cotonete_na_boca_e_ou_nariz_swab|qual_o_resultado|fez_o_exame_de_coleta_de_sangue_atraves_de_furo_no_dedo|qual_o_resultado|fez_o_exame_de_coleta_de_sangue_atraves_da_veia_da_braco|qual_o_resultado|algum_medico_ja_lhe_deu_o_diagnostico_de_diabetes|algum_medico_ja_lhe_deu_o_diagnostico_de_hipertensao|algum_medico_ja_lhe_deu_o_diagnostico_de_asma_bronquite_enfisema_doencas_respiratoria_cronica_ou_doenca_de_pulmao|algum_medico_ja_lhe_deu_o_diagnostico_de_doencas_do_coracao_infarto_angina_insuficiencia_cardiaca_arritmia|algum_medico_ja_lhe_deu_o_diagnostico_de_depressao|algum_medico_ja_lhe_deu_o_diagnostico_de_cancer|qual_foi_o_resultado_do_teste_na_semana_passada_devido_a_pandemia_do_coronavirus_em_que_medida_o_a_sr_a_restringiu_o_contato_com_as_pessoas|na_semana_passada_por_pelo_menos_uma_hora_trabalhou_ou_fez_algum_bico|na_semana_passada_estava_temporariamente_afastado_de_algum_trabalho|qual_o_principal_motivo_deste_afastamento_temporario|continuou_a_ser_remunerado_mesmo_que_parcialmente_por_esse_trabalho|ha_quanto_tempo_esta_afastado_desse_trabalho|tempo_que_estava_afastado_de_1_mes_a_menos_de_ ...
# +---+-----------------+--------------------+-----------------------------+------------------------------------------------------+------------------------------+-------------+---------------+---------------------------------+-------+---------+---------------------+------------+---------------------+-------------------------------+-------------------------------+--------------------+---------------+-------------------------------------------+-----------------+-----------------+-----------------+----------------+------+-----------+----------------------+----------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+----------------------------------------------------------------+-----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+-------------------------------------------------------+----------------+--------------------------------------------------------+----------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+---------------------------------------------- ...
# |1  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |1                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |152677               |133.93337786                   |164.20936068                   |1114                |1              |Pessoa responsável pelo domicílio          |5                |8                |1984             |36              |Homem |Parda      |Médio completo        |null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |2  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |1                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |150642               |133.93337786                   |166.94461021                   |1124                |2              |Cônjuge ou companheiro(a) de sexo diferente|18               |8                |1990             |30              |Mulher|Parda      |Superior completo     |null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |3  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |1                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |145237               |133.93337786                   |171.88775372                   |1112                |3              |Filho(a) do responsável e do cônjuge       |25               |12               |2006             |13              |Homem |Parda      |Fundamental incompleto|Sim             |Sim, e realizou pelo menos parte delas                                             |5 dias                                                              |De 2 horas a menos de 5 horas                                                          |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou rigorosamente em casa                                                                                                                |null                                                                 |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |4  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |1                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |145237               |133.93337786                   |171.88775372                   |1112                |4              |Filho(a) do responsável e do cônjuge       |24               |8                |2009             |11              |Homem |Parda      |Fundamental incompleto|Sim             |Sim, e realizou pelo menos parte delas                                             |5 dias                                                              |De 2 horas a menos de 5 horas                                                          |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou rigorosamente em casa                                                                                                                |null                                                                 |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |5  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |2                             |1            |9              |5                                |1110011|110015970|Urbana               |Capital     |91889                |133.93337786                   |127.53668218                   |1126                |1              |Pessoa responsável pelo domicílio          |18               |5                |1963             |57              |Mulher|Branca     |Fundamental incompleto|null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                                           ...
# |6  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |3                             |2            |9              |5                                |1110011|110015970|Urbana               |Capital     |91889                |133.93337786                   |127.53668218                   |1126                |1              |Pessoa responsável pelo domicílio          |25               |12               |1961             |58              |Mulher|Preta      |Sem instrução         |null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Sim                                              |Sim                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou em casa e só saiu em caso de necessidade básica                                                                                      |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |7  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |4                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |123242               |133.93337786                   |164.39829286                   |1115                |1              |Pessoa responsável pelo domicílio          |18               |2                |1973             |47              |Homem |Parda      |Fundamental incompleto|null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |8  |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |4                             |4            |9              |5                                |1110011|110015970|Urbana               |Capital     |139056               |133.93337786                   |163.71468056                   |1122                |4              |Filho(a) somente do responsável            |Não informado    |Não informado    |9999             |18              |Mulher|Parda      |Fundamental incompleto|Não             |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou em casa e só saiu em caso de necessidade básica                                                                                      |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                                           ...
# ...
# |19 |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |6                             |2            |9              |5                                |1110011|110015970|Urbana               |Capital     |95808                |133.93337786                   |146.59504674                   |1116                |2              |Cônjuge ou companheiro(a) de sexo diferente|29               |5                |1967             |53              |Homem |Preta      |Fundamental incompleto|null            |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou em casa e só saiu em caso de necessidade básica                                                                                      |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |null                                           ...
# |20 |2020             |Rondônia            |Município de Porto Velho (RO)|null                                                  |6                             |2            |9              |5                                |1110011|110015970|Urbana               |Capital     |139056               |133.93337786                   |163.71468056                   |1122                |3              |Filho(a) do responsável e do cônjuge       |20               |12               |2002             |17              |Mulher|Branca     |Médio incompleto      |Não             |null                                                                               |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                            |null                                                                                     |null                                                                                           |null                                                                                               |null                                                                                                                                                     |null                                                                                                 |null                                                    |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null                                                   |null            |null                                                    |null            |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                                           ...
# +---+-----------------+--------------------+-----------------------------+------------------------------------------------------+------------------------------+-------------+---------------+---------------------------------+-------+---------+---------------------+------------+---------------------+-------------------------------+-------------------------------+--------------------+---------------+-------------------------------------------+-----------------+-----------------+-----------------+----------------+------+-----------+----------------------+----------------+-----------------------------------------------------------------------------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+----------------------------------------------------------------+-----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+-------------------------------------------------------+----------------+--------------------------------------------------------+----------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+---------------------------------------------- ...
# only showing top 20 rows

# %%
from collections import defaultdict

def rename_duplicate_columns(df):
    counts = defaultdict(int)
    new_columns = []

    for c in df.columns:
        counts[c] += 1
        if counts[c] == 1:
            new_columns.append(c)
        else:
            new_columns.append(f"{c}_{counts[c]}")

    return df.toDF(*new_columns)

micro_traduzido_corrigido = rename_duplicate_columns(micro_traduzido)

# %%
micro_traduzido_corrigido.write \
    .format("parquet") \
    .mode("overwrite") \
    .option("path", "s3://lab-746762238259/data-output/pnad_covid_silver/") \
    .option("compression", "snappy") \
    .saveAsTable("workspace.tb_pnad_covid_silver")

# %% [markdown]
# ### Contagem de linhas de dados do dataframe
#
# Descrição:
# Exibe a quantidade de linhas do dataframe

# %%
micro_traduzido.count()
# Out:
# 1149197

# %% [markdown]
# # CAMADA GOLD
# ### Visualização dos Dados com as Colunas
#
# Descrição:
# Exibe as primeiras linhas do DataFrame de microdados após a tradução, mostrando os valores já convertidos em formato legível.

# %%
from pyspark.sql import functions as F

# =====================================================
# Lista FINAL de colunas desejadas (já corrigida)
# =====================================================
colunas_selecionadas = [
    "ano_de_referencia",
    "unidade_da_federacao",
    "capital",
    "regiao_metropolitana_e_regiao_administrativa_integrada_de_desenvolvimento",
    "semana_no_mes",
    "mes_da_pesquisa",
    "estrato",
    "upa",
    "situacao_do_domicilio",
    "tipo_de_area",
    "dominios_de_projecao",
    "condicao_no_domicilio",
    "idade_do_morador",
    "sexo",
    "cor_ou_raca",
    "escolaridade",
    "frequenta_escola",
    "na_semana_passada_em_quantos_dias_dedicou_se_as_atividades_escolares",
    "na_semana_passada_quanto_tempo_por_dia_gastou_fazendo_as_atividades_escolares_escolares",
    "na_semana_passada_teve_febre",
    "na_semana_passada_teve_tosse",
    "na_semana_passada_teve_dor_de_garganta",
    "na_semana_passada_teve_dificuldade_para_respirar",
    "na_semana_passada_teve_dor_de_cabeca",
    "na_semana_passada_teve_dor_no_peito",
    "na_semana_passada_teve_nausea",
    "na_semana_passada_teve_nariz_entupido_ou_escorrendo",
    "na_semana_passada_teve_fadiga",
    "na_semana_passada_teve_dor_nos_olhos",
    "na_semana_passada_teve_perda_de_cheiro_ou_sabor",
    "na_semana_passada_teve_dor_muscular",
    "na_semana_passada_teve_diarreia",
    "por_causa_disso_foi_a_algum_estabelecimento_de_saude",
    "local_que_buscou_atendimento_foi_posto_de_saude_unidade_basica_de_saude_equipe_de_saude_da_familia_medico_enfermeiro_tecnico_de_enfermagem_ou_agente_comunitario_de_saude",
    "local_que_buscou_atendimento_foi_pronto_socorro_do_sus_upa",
    "local_que_buscou_atendimento_foi_hospital_do_sus",
    "local_que_buscou_atendimento_foi_ambulatorio_ou_consultorio_privado_ou_ligado_as_forcas_armadas",
    "local_que_buscou_atendimento_foi_pronto_socorro_privado_ou_ligado_as_forcas_armadas",
    "local_que_buscou_atendimento_foi_hospital_privado_ou_ligado_as_forcas_armadas",
    "ao_procurar_o_hospital_teve_que_ficar_internado_por_um_dia_ou_mais",
    "durante_a_internacao_foi_sedado_entubado_e_colocado_em_respiracao_artificial_com_ventilador",
    "tem_algum_plano_de_saude_medico_seja_particular_de_empresa_ou_de_orgao_publico",
    "o_a_sr_a_fez_algum_teste_para_saber_se_estava_infectado_a_pelo_coronavirus",
    "fez_o_exame_coletado_com_cotonete_na_boca_e_ou_nariz_swab",
    "qual_o_resultado",
    "qual_o_resultado_2",
    "qual_o_resultado_3",
    "fez_o_exame_de_coleta_de_sangue_atraves_de_furo_no_dedo",
    "fez_o_exame_de_coleta_de_sangue_atraves_da_veia_da_braco",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_diabetes",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_hipertensao",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_asma_bronquite_enfisema_doencas_respiratoria_cronica_ou_doenca_de_pulmao",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_doencas_do_coracao_infarto_angina_insuficiencia_cardiaca_arritmia",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_depressao",
    "algum_medico_ja_lhe_deu_o_diagnostico_de_cancer",
    "qual_foi_o_resultado_do_teste_na_semana_passada_devido_a_pandemia_do_coronavirus_em_que_medida_o_a_sr_a_restringiu_o_contato_com_as_pessoas",
    "na_semana_passada_por_pelo_menos_uma_hora_trabalhou_ou_fez_algum_bico",
    "na_semana_passada_estava_temporariamente_afastado_de_algum_trabalho",
    "qual_o_principal_motivo_deste_afastamento_temporario",
    "continuou_a_ser_remunerado_mesmo_que_parcialmente_por_esse_trabalho",
    "ha_quanto_tempo_esta_afastado_desse_trabalho",
    "tem_mais_de_um_trabalho",
    "no_trabalho_unico_ou_principal_que_tinha_nessa_semana_era",
    "esse_trabalho_era_na_area",
    "tem_carteira_de_trabalho_assinada_ou_e_funcionario_publico_estatutario",
    "que_tipo_de_trabalho_cargo_ou_funcao_voce_realiza_no_seu_trabalho_unico_ou_principal",
    "qual_e_a_principal_atividade_do_local_ou_empresa_em_que_voce_trabalha",
    "na_semana_passada_quantos_empregados_trabalhavam_nesse_negocio_empresa_que_tinha",
    "quantas_horas_por_semana_normalmente_trabalhava",
    "quantas_horas_na_semana_passada_de_fato_trabalhou",
    "na_semana_passada_o_a_sr_a_gostaria_de_ter_trabalhado_mais_horas_do_que_as_de_fato_trabalhadas",
    "quanto_recebia_ou_retirava_normalmente_em_todos_os_seus_trabalhos",
    "recebia_retirava_normalmente_em_dinheiro",
    "recebia_normalmente_em_produtos_e_mercadorias",
    "era_nao_remunerado",
    "quanto_recebia_ou_retirava_efetivamente_em_todos_os_seus_trabalhos",
    "recebia_retirava_efetivamente_em_dinheiro",
    "recebia_efetivamente_em_produtos_e_mercadorias",
    "na_maior_parte_do_tempo_na_semana_passada_esse_trabalho_unico_ou_principal_foi_exercido_no_mesmo_local_em_que_costuma_trabalhar",
    "na_semana_passada_o_a_sr_a_estava_em_trabalho_remoto_home_office_ou_teletrabalho",
    "o_a_sr_a_contribui_para_o_inss",
    "na_semana_passada_tomou_alguma_providencia_efetiva_para_conseguir_trabalho",
    "qual_o_principal_motivo_de_nao_ter_procurado_trabalho_na_semana_passada",
    "embora_voce_nao_tenha_procurado_trabalho_gostaria_de_ter_trabalhado_na_semana_passada",
    "rendimento_recebido_de_aposentadoria_e_pensao_por_todos_os_moradores",
    "rendimento_de_pensao_alimenticia_doacao_ou_mesada_em_dinheiro_de_pessoa_que_nao_morava_no_domicilio",
    "rendimentos_de_programa_bolsa_familia",
    "auxilios_emergenciais_relacionados_ao_coronavirus",
    "seguro_desemprego",
    "outros_rendimentos_como_aluguel_arrendamento_previdencia_privada_bolsa_de_estudos_rendimentos_de_aplicacao_financeira_etc",
    "durante_o_periodo_da_pandemia_alguem_deste_domicilio_solicitou_algum_emprestimo",
    "este_emprestimo_foi_adquirido_com_banco_ou_financeira",
    "este_emprestimo_foi_adquirido_com_parente_ou_amigo",
    "este_emprestimo_foi_adquirido_com_empregados_ou_patrao",
    "este_emprestimo_foi_adquirido_com_outro_local_ou_pessoa",
    "este_domicilio_e",
    "qual_foi_o_valor_mensal_do_aluguel_pago_ou_que_deveria_ter_sido_pago_no_mes_de_referencia",
    "numero_da_faixa_do_aluguel_pago",
    "quem_respondeu_ao_questionario",
    "numero_de_ordem_do_morador_que_prestou_as_informacoes"
]

# =====================================================
# 2. Seleção segura (apenas colunas existentes)
# =====================================================
colunas_existentes = set(micro_traduzido_corrigido.columns)

colunas_validas = [
    F.col(c) for c in colunas_selecionadas if c in colunas_existentes
]

colunas_ausentes = [
    c for c in colunas_selecionadas if c not in colunas_existentes
]

if colunas_ausentes:
    print("⚠️ Colunas não encontradas e ignoradas:")
    for c in colunas_ausentes:
        print(" -", c)

# =====================================================
# 3. DataFrame final
# =====================================================
df_selecionado = micro_traduzido_corrigido.select(colunas_validas)

# =====================================================
# 4. Visualização
# =====================================================
df_selecionado.show(50, truncate=False)
# Out:
# ⚠️ Colunas não encontradas e ignoradas:
#  - regiao_metropolitana_e_regiao_administrativa_integrada_de_desenvolvimento
# +-----------------+--------------------+-----------------------------+-------------+---------------+-------+---------+---------------------+------------+--------------------+------------------------------------------------------+----------------+------+-----------+----------------------+----------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+------------------+------------------+-------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+-----------------------+-----------------------------------------------------------------+-------------------------+----------------------------------------------------------------------+------------------------------------------------------------------------------------+-----------------------------------------------------------------------+--------------------------------------------------------------------------------+-----------------------------------------------+-------------------------------------------------+----------------------------------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------+---------------------------------------------+------------------+------------------------------------------------------------------+-----------------------------------------+----------------------------------------------+----------------------------------------------------------------------------------------------------------------- ...
# |ano_de_referencia|unidade_da_federacao|capital                      |semana_no_mes|mes_da_pesquisa|estrato|upa      |situacao_do_domicilio|tipo_de_area|dominios_de_projecao|condicao_no_domicilio                                 |idade_do_morador|sexo  |cor_ou_raca|escolaridade          |frequenta_escola|na_semana_passada_em_quantos_dias_dedicou_se_as_atividades_escolares|na_semana_passada_quanto_tempo_por_dia_gastou_fazendo_as_atividades_escolares_escolares|na_semana_passada_teve_febre|na_semana_passada_teve_tosse|na_semana_passada_teve_dor_de_garganta|na_semana_passada_teve_dificuldade_para_respirar|na_semana_passada_teve_dor_de_cabeca|na_semana_passada_teve_dor_no_peito|na_semana_passada_teve_nausea|na_semana_passada_teve_nariz_entupido_ou_escorrendo|na_semana_passada_teve_fadiga|na_semana_passada_teve_dor_nos_olhos|na_semana_passada_teve_perda_de_cheiro_ou_sabor|na_semana_passada_teve_dor_muscular|na_semana_passada_teve_diarreia|por_causa_disso_foi_a_algum_estabelecimento_de_saude|local_que_buscou_atendimento_foi_posto_de_saude_unidade_basica_de_saude_equipe_de_saude_da_familia_medico_enfermeiro_tecnico_de_enfermagem_ou_agente_comunitario_de_saude|local_que_buscou_atendimento_foi_pronto_socorro_do_sus_upa|local_que_buscou_atendimento_foi_hospital_do_sus|local_que_buscou_atendimento_foi_ambulatorio_ou_consultorio_privado_ou_ligado_as_forcas_armadas|local_que_buscou_atendimento_foi_pronto_socorro_privado_ou_ligado_as_forcas_armadas|local_que_buscou_atendimento_foi_hospital_privado_ou_ligado_as_forcas_armadas|ao_procurar_o_hospital_teve_que_ficar_internado_por_um_dia_ou_mais|durante_a_internacao_foi_sedado_entubado_e_colocado_em_respiracao_artificial_com_ventilador|tem_algum_plano_de_saude_medico_seja_particular_de_empresa_ou_de_orgao_publico|o_a_sr_a_fez_algum_teste_para_saber_se_estava_infectado_a_pelo_coronavirus|fez_o_exame_coletado_com_cotonete_na_boca_e_ou_nariz_swab|qual_o_resultado|qual_o_resultado_2|qual_o_resultado_3|fez_o_exame_de_coleta_de_sangue_atraves_de_furo_no_dedo|fez_o_exame_de_coleta_de_sangue_atraves_da_veia_da_braco|algum_medico_ja_lhe_deu_o_diagnostico_de_diabetes|algum_medico_ja_lhe_deu_o_diagnostico_de_hipertensao|algum_medico_ja_lhe_deu_o_diagnostico_de_asma_bronquite_enfisema_doencas_respiratoria_cronica_ou_doenca_de_pulmao|algum_medico_ja_lhe_deu_o_diagnostico_de_doencas_do_coracao_infarto_angina_insuficiencia_cardiaca_arritmia|algum_medico_ja_lhe_deu_o_diagnostico_de_depressao|algum_medico_ja_lhe_deu_o_diagnostico_de_cancer|qual_foi_o_resultado_do_teste_na_semana_passada_devido_a_pandemia_do_coronavirus_em_que_medida_o_a_sr_a_restringiu_o_contato_com_as_pessoas|na_semana_passada_por_pelo_menos_uma_hora_trabalhou_ou_fez_algum_bico|na_semana_passada_estava_temporariamente_afastado_de_algum_trabalho|qual_o_principal_motivo_deste_afastamento_temporario|continuou_a_ser_remunerado_mesmo_que_parcialmente_por_esse_trabalho|ha_quanto_tempo_esta_afastado_desse_trabalho|tem_mais_de_um_trabalho|no_trabalho_unico_ou_principal_que_tinha_nessa_semana_era        |esse_trabalho_era_na_area|tem_carteira_de_trabalho_assinada_ou_e_funcionario_publico_estatutario|que_tipo_de_trabalho_cargo_ou_funcao_voce_realiza_no_seu_trabalho_unico_ou_principal|qual_e_a_principal_atividade_do_local_ou_empresa_em_que_voce_trabalha  |na_semana_passada_quantos_empregados_trabalhavam_nesse_negocio_empresa_que_tinha|quantas_horas_por_semana_normalmente_trabalhava|quantas_horas_na_semana_passada_de_fato_trabalhou|na_semana_passada_o_a_sr_a_gostaria_de_ter_trabalhado_mais_horas_do_que_as_de_fato_trabalhadas|quanto_recebia_ou_retirava_normalmente_em_todos_os_seus_trabalhos|recebia_retirava_normalmente_em_dinheiro|recebia_normalmente_em_produtos_e_mercadorias|era_nao_remunerado|quanto_recebia_ou_retirava_efetivamente_em_todos_os_seus_trabalhos|recebia_retirava_efetivamente_em_dinheiro|recebia_efetivamente_em_produtos_e_mercadorias|na_maior_parte_do_tempo_na_semana_passada_esse_trabalho_unico_ou_principal_foi_exercido_no_mesmo_local_em_que_cos ...
# +-----------------+--------------------+-----------------------------+-------------+---------------+-------+---------+---------------------+------------+--------------------+------------------------------------------------------+----------------+------+-----------+----------------------+----------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+------------------+------------------+-------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+-----------------------+-----------------------------------------------------------------+-------------------------+----------------------------------------------------------------------+------------------------------------------------------------------------------------+-----------------------------------------------------------------------+--------------------------------------------------------------------------------+-----------------------------------------------+-------------------------------------------------+----------------------------------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------+---------------------------------------------+------------------+------------------------------------------------------------------+-----------------------------------------+----------------------------------------------+----------------------------------------------------------------------------------------------------------------- ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1114                |Pessoa responsável pelo domicílio                     |36              |Homem |Parda      |Médio completo        |null            |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |Não                    |Empregado do setor privado                                       |null                     |Sim, tem carteira de trabalho assinada                                |Outro técnico ou profissional de nível médio                                        |Comércio no atacado e varejo;                                          |null                                                                            |48                                             |48                                               |null                                                                                          |Indica se o quesito foi respondido                               |Em dinheiro                             |null                                         |null              |Indica se o quesito foi respondido                                |Em dinheiro                              |null                                          |Sim                                                                                                               ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1124                |Cônjuge ou companheiro(a) de sexo diferente           |30              |Mulher|Parda      |Superior completo     |null            |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |Não                    |Conta própria                                                    |null                     |null                                                                  |Técnico, profissional da saúde de nível médio                                       |Saúde humana e assistência social                                      |null                                                                            |36                                             |36                                               |Não                                                                                           |Indica se o quesito foi respondido                               |Em dinheiro                             |null                                         |null              |Indica se o quesito foi respondido                                |Em dinheiro                              |null                                          |Sim                                                                                                               ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1112                |Filho(a) do responsável e do cônjuge                  |13              |Homem |Parda      |Fundamental incompleto|Sim             |5 dias                                                              |De 2 horas a menos de 5 horas                                                          |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou rigorosamente em casa                                                                                                                |null                                                                 |null                                                               |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1112                |Filho(a) do responsável e do cônjuge                  |11              |Homem |Parda      |Fundamental incompleto|Sim             |5 dias                                                              |De 2 horas a menos de 5 horas                                                          |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Sim                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou rigorosamente em casa                                                                                                                |null                                                                 |null                                                               |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|1            |9              |1110011|110015970|Urbana               |Capital     |1126                |Pessoa responsável pelo domicílio                     |57              |Mulher|Branca     |Fundamental incompleto|null            |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|2            |9              |1110011|110015970|Urbana               |Capital     |1126                |Pessoa responsável pelo domicílio                     |58              |Mulher|Preta      |Sem instrução         |null            |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Sim                                              |Sim                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou em casa e só saiu em caso de necessidade básica                                                                                      |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |Não                    |Conta própria                                                    |null                     |null                                                                  |Outros                                                                              |Outro                                                                  |null                                                                            |40                                             |40                                               |null                                                                                          |Indica se o quesito foi respondido                               |Em dinheiro                             |null                                         |null              |Indica se o quesito foi respondido                                |Em dinheiro                              |null                                          |Sim                                                                                                               ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1115                |Pessoa responsável pelo domicílio                     |47              |Homem |Parda      |Fundamental incompleto|null            |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Sim                                                                  |null                                                               |null                                                |null                                                               |null                                        |Não                    |Conta própria                                                    |null                     |null                                                                  |Pedreiro, servente de pedreiro, pintor, eletricista, marceneiro                     |Construção                                                             |null                                                                            |40                                             |20                                               |Sim                                                                                           |Indica se o quesito foi respondido                               |Em dinheiro                             |null                                         |null              |Indica se o quesito foi respondido                                |Em dinheiro                              |null                                          |Sim                                                                                                               ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|4            |9              |1110011|110015970|Urbana               |Capital     |1122                |Filho(a) somente do responsável                       |18              |Mulher|Parda      |Fundamental incompleto|Não             |null                                                                |null                                                                                   |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou em casa e só saiu em caso de necessidade básica                                                                                      |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|3            |9              |1110011|110011734|Urbana               |Capital     |1112                |Filho(a) somente do responsável                       |17              |Homem |Preta      |Médio incompleto      |Sim             |6 ou 7 dias                                                         |5 horas ou mais                                                                        |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas           |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# |2020             |Rondônia            |Município de Porto Velho (RO)|3            |9              |1110011|110011734|Urbana               |Capital     |1112                |Filho(a) somente do responsável                       |15              |Homem |Parda      |Médio incompleto      |Sim             |6 ou 7 dias                                                         |5 horas ou mais                                                                        |Não                         |Não                         |Não                                   |Não                                             |Não                                 |Não                                |Não                          |Não                                                |Não                          |Não                                 |Não                                            |Não                                |Não                            |null                                                |null                                                                                                                                                                     |null                                                      |null                                            |null                                                                                           |null                                                                               |null                                                                         |null                                                              |null                                                                                       |Não                                                                           |Não                                                                       |null                                                     |null            |null              |null              |null                                                   |null                                                    |Não                                              |Não                                                 |Não                                                                                                              |Não                                                                                                       |Não                                               |Não                                            |Ficou rigorosamente em casa                                                                                                                |Não                                                                  |Não                                                                |null                                                |null                                                               |null                                        |null                   |null                                                             |null                     |null                                                                  |null                                                                                |null                                                                   |null                                                                            |null                                           |null                                             |null                                                                                          |null                                                             |null                                    |null                                         |null              |null                                                              |null                                     |null                                          |null                                                                                                              ...
# +-----------------+--------------------+-----------------------------+-------------+---------------+-------+---------+---------------------+------------+--------------------+------------------------------------------------------+----------------+------+-----------+----------------------+----------------+--------------------------------------------------------------------+---------------------------------------------------------------------------------------+----------------------------+----------------------------+--------------------------------------+------------------------------------------------+------------------------------------+-----------------------------------+-----------------------------+---------------------------------------------------+-----------------------------+------------------------------------+-----------------------------------------------+-----------------------------------+-------------------------------+----------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------+------------------------------------------------+-----------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------------------------------------------------------+------------------------------------------------------------------------------+--------------------------------------------------------------------------+---------------------------------------------------------+----------------+------------------+------------------+-------------------------------------------------------+--------------------------------------------------------+-------------------------------------------------+----------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------+--------------------------------------------------+-----------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+----------------------------------------------------+-------------------------------------------------------------------+--------------------------------------------+-----------------------+-----------------------------------------------------------------+-------------------------+----------------------------------------------------------------------+------------------------------------------------------------------------------------+-----------------------------------------------------------------------+--------------------------------------------------------------------------------+-----------------------------------------------+-------------------------------------------------+----------------------------------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------+---------------------------------------------+------------------+------------------------------------------------------------------+-----------------------------------------+----------------------------------------------+----------------------------------------------------------------------------------------------------------------- ...
# only showing top 50 rows

# %%
df_selecionado.write \
    .format("parquet") \
    .mode("overwrite") \
    .option("path", "s3://lab-746762238259/data-output/pnad_covid_gold/") \
    .option("compression", "snappy") \
    .saveAsTable("workspace.tb_pnad_covid_gold")
